# %%
# -*- coding: utf-8 -*
import argparse
import tensorflow as tf
from flyai.dataset import Dataset

from model import Model
from path import MODEL_PATH

# 数据获取辅助类
dataset = Dataset()
# 模型操作辅助类
model = Model(dataset)

# %%
a= dataset.db.source.data

# %%
dataset.get_all_data()
# Out:
# ([{'news': '马云又出惊人言论，8年后房子最不值钱，他的话可信吗？', 'keywords': nan},
#   {'news': '上联：泰山黄山赵本山，如何对下联？', 'keywords': nan},
#   {'news': '为什么现在没有人玩CS了？', 'keywords': nan},
#   {'news': '京东白条还款逾期了半个月，会影响个人征信吗？', 'keywords': nan},
#   {'news': '长洲教育大家谈第二期主题公告', 'keywords': '社会主义,长洲教育大家谈,长洲,核心价值观,核心价值观融入'},
#   {'news': '脐橙卷叶？原因竟然是这个！', 'keywords': '卷叶,脐橙,线虫,脐橙卷叶,脐橙卷'},
#   {'news': '这人驾驶技术真好，开着大型轰炸机降落在航空母舰上', 'keywords': '轰炸机,航空母舰'},
#   {'news': '马云持股少，但没想到，刘强东持股也少', 'keywords': '刘强东,京东集团,阿里巴巴,蔡崇信,马云'},
#   {'news': '卖军火已成精，飞机便宜给你，后续靠弹药也能赚翻',
#    'keywords': '彩虹-5,中航工业,中国北方工业公司,MBDA,EF2000,弹药'},
#   {'news': '山东为什么盛产美男？', 'keywords': nan},
#   {'news': '美好生活，与你同在，5年时间，太原的你离不开它', 'keywords': '同城,58同城,太原'},
#   {'news': 'FPS游戏《原子之心》公布 另一条世界线的故事',
#    'keywords': 'FPS游戏,原子之心,传奇,全民捕鱼赢话费,机器人,太平洋,口袋妖怪'},
#   {'news': '谷歌介绍自适应电池功能', 'keywords': '马斯洛,WiFi,自适应电池功能,谷歌,CPU'},
#   {'news': '连奥巴马都忍不了了，猛烈抨击特朗普，还要一意孤行吗？', 'keywords': '伊朗核协议,特朗普,共和党,美国,盟友'},
#   {'news': '国家宣战权有何用处，不宣而战又会怎么样？', 'keywords': '缔约国,不宣而战,自卫队,宣战权,日内瓦四公约'},
#   {'news': '怎样看待当前地域黑的问题？', 'keywords': nan},
#   {'news': '不要阿兰不要高拉特！恒大球迷要求回购一人，他让两大名帅后悔',
#    'keywords': '金英权,高拉特,卡纳瓦罗,中超联赛,穆里奇'},
#   {'news': '量子点电视将引领高端电视领域新航向', 'keywords': '高端产品,量子点,量子点电视,消费升级,彩电产品'},
#   {'news': '赵薇、范冰冰、林心如，你觉得谁最漂亮？', 'keywords': nan},
#   {'news': '伊朗为什么宁愿接受制裁也不同意修改伊核协议？', 'keywords': nan},
#   {'news': '富士康总裁郭台铭放话：未来电商平台可能会消失！你怎么看？马云怎么办？',
#    'keywords': '用户端,电子商务,阿里巴巴,实体经济,马云,电商平台'},
#   {'news': '毛泽东：西江月秋收起义', 'keywords': '秋收起义,毛泽东'},
#   {'news': '「践行四种人」“消薄增收”我们在行动', 'keywords': '桃源村,洪家村,浪川乡,消薄增收,农村'},
#   {'news': '张钧甯撞衫毛晓彤，网友：妇女和仙女的差距一目了然', 'keywords': '连衣裙,仙女,张钧甯,毛晓彤'},
'news': '马云判断未来房价会便宜如白菜，是基于什么逻辑？', 'keywords': nan},
#   {'news': 'MSI季中赛RNG对战KZ时战败，是谁的锅？', 'keywords': nan},
#   {'news': '政策调整 “限价房”可转共有产权', 'keywords': '共有产权住房,保障房,限房价项目,评估价,共有产权房'},
#   {'news': '声明：Oculus Research正式更名为Facebook Reality Labs',
#    'keywords': 'Labs,Facebook,材料科学,实验室,Oculus'},
#   {'news': 'iPhone 6s有一点问题，耗电很快是为什么？', 'keywords': 'iPhone,iphone 6s'},
#   {'news': '最后一周，0基础通过初级会计职称，就靠这4招秘诀了！',
#    'keywords': '都有为,会计学,了解更多,会计,经济法基础,会计分录,跟着笨笨干会计,零基础学会计,初级会计实务,会计入门全知道'},
#   {'news': '比亚迪再获美国洛杉矶机场20台电动大巴订单，厉害了我的迪！', 'keywords': '比亚迪,洛杉矶,洛杉矶机场,美国'},
#   {'news': '库蒂尼奥接受采访时说：“我不想继承梅西的10号球衣”对此，你怎么评价？', 'keywords': nan},
#   {'news': '宝莲灯9月将翻拍，粉丝总结5位经典角色，第3位有人敢接吗？',
#    'keywords': '宝莲灯前传,宝莲灯,小狐狸,寻秦记,沉香,笑傲江湖,二郎神,焦恩俊,亮剑,三圣母'},
#   {'news': '年轻人的设计 “大排量”与省油兼得 这样的日系车不了解一下？',
#    'keywords': 'MINI,B级车,HYBRID,帕萨特,阿特兹,雷克萨斯,凯美瑞,TNGA,马自达,大排量,混动车,卡罗拉,普锐斯,省油,E-CVT,奥迪A3'},
#   {'news': '华为mate9和华为mate9pro哪个好？',
#    'keywords': '机身,华为Mate9,双曲面,Mate9 Pro,华为Mate9 Pro'},
#   {'news': '月薪5000元在北京是什么样的水平？', 'keywords': '月薪,月薪5000,北京,地下室,王二娃'},
#   {'news': '为什么有时候大姨妈会越来越少？', 'keywords': nan},
#   {'news': '12日热点新闻：国产航母来不及沾沾自喜，仍迫切需要提升舰载机支持能力',
#    'keywords': '国产航母,RNG,奥巴马,辽宁舰,特朗普'},
#   {'news': '三星诚意回馈中国消费者，多款旗舰机型迎来夏季狂欢节',
#    'keywords': 'Galaxy S9,手机零售指数,三星Galaxy,迪信通,三星,智能手机'},
#   {'news': '能把孤独写得这样透彻，除了林语堂其他人都做不到', 'keywords': '林语堂,近现代,左与右,中国作家'},
#   {'news': '论音乐的重要性 梦幻西游玩家依靠听歌竟成为全服第一红？',
#    'keywords': '恭喜发财,纯音乐,借我,轻音乐,理想三旬,in the end,今天是个好日子,梦幻西游,定西,雪之梦,开箱子时,好运来,金刚石'},
#   {'news': '“机蜜”全攻略：小米上市在即，酷派为蹭热度不惜自残！', 'keywords': '运营商,小米,贾跃亭,智能机,酷派'},
#   {'news': '伊核协议出现新的转机，特朗普推特发出周二宣布对伊朗协议的决定！',
#    'keywords': '默克尔,伊朗,伊核协议,唐纳德·特朗普,马克龙'},
#   {'news': '五月正吃的营养水果——甜瓜，营养价值高，味道甘甜可口！',
#    'keywords': '甜瓜新鲜,水果,羊角蜜,精选阎良甜瓜,甜香多汁'},
#   {'news': '福利来了 2018年兰州五十四中分校进入九州 并于8月开始招生', 'keywords': '九州,兰州'},
#   {'news': '想学人工智能？不用去新东方，在临颍都能学！', 'keywords': '临颍,机器人,新东方,临颍县,人工智能'},
#   {'news': '旅行带给大家最大的收获是什么？', 'keywords': nan},
#   {'news': '深圳炒房的人现在都怎么样了？套现了吗？', 'keywords': '房产,深圳,炒房客,房价,市场价'},
#   {'news': '你以为我英语8级啊？Steam上急需中文的三款游戏',
#    'keywords': '网络游戏,上古卷轴,策略游戏,Steam平台,汉化'},
#   {'news': 'LOL：FNC自信过头，五人草丛埋伏，Uzi一招吓得敌方水晶爆了！',
#    'keywords': 'FNC,RNG,UZI,MSI,英雄联盟'},
#   {'news': '王者荣耀：一级想安心打buff？捣乱者不去野区搞点事情就太可惜了', 'keywords': '钟馗,在野区,打野,buff'}],
#  [{'category': 'news_house'},
#   {'category': 'news_culture'},
#   {'category': 'news_game'},
#   {'category': 'news_tech'},
#   {'category': 'news_edu'},
#   {'category': 'news_agriculture'},
#   {'category': 'news_military'},
#   {'category': 'news_finance'},
#   {'category': 'news_military'},
#   {'category': 'news_travel'},
#   {'category': 'news_agriculture'},
#   {'category': 'news_game'},
#   {'category': 'news_tech'},
#   {'category': 'news_world'},
#   {'category': 'news_military'},
#   {'category': 'news_edu'},
#   {'category': 'news_sports'},
#   {'category': 'news_finance'},
#   {'category': 'news_entertainment'},
#   {'category': 'news_world'},
#   {'category': 'news_tech'},
#   {'category': 'news_agriculture'},
#   {'category': 'news_agriculture'},
#   {'category': 'news_entertainment'},
#   {'category': 'news_agriculture'},
#   {'category': 'news_story'},
#   {'category': 'news_edu'},
#   {'category': 'news_game'},
#   {'category': 'news_entertainment'},
#   {'category': 'news_car'},
#   {'category': 'news_sports'},
#   {'category': 'news_sports'},
#   {'category': 'news_entertainment'},
#   {'category': 'news_car'},
#   {'category': 'news_culture'},
#   {'category': 'news_story'},
#   {'category': 'news_culture'},
#   {'category': 'news_edu'},
#   {'category': 'news_military'},
#   {'category': 'news_sports'},
#   {'category': 'news_house'},
#   {'category': 'news_game'},
#   {'category': 'news_military'},
#   {'category': 'news_car'},
#   {'category': 'news_finance'},
#   {'category': 'news_military'},
#   {'category': 'news_edu'},
#   {'category': 'news_tech'},
#   {'category': 'news_edu'},
#   {'category': 'news_house'},
#   {'category': 'news_finance'},
#   {'category': 'news_tech'},
#   {'category': 'news_world'},
#   {'category': 'news_entertainment'},
#   {'category': 'news_travel'},
#   {'category': 'news_sports'},
#   {'category': 'news_entertainment'},
#   {'category': 'news_tech'},
#   {'category': 'news_finance'},
#   {'category': 'news_tech'},
#   {'category': 'news_car'},
#   {'category': 'news_game'},
#   {'category': 'news_car'},
#   {'category': 'news_edu'},
#   {'category': 'news_agriculture'},
#   {'category': 'news_car'},
#   {'category': 'news_finance'},
#   {'category': 'news_finance'},
#   {'category': 'news_sports'},
#   {'category': 'news_travel'},
#   {'category': 'news_sports'},
#   {'category': 'news_house'},
#   {'category': 'news_culture'},
#   {'category': 'news_house'},
#   {'category': 'news_game'},
#   {'category': 'news_house'},
#   {'category': 'news_tech'},
#   {'category': 'news_tech'},
#   {'category': 'news_edu'},
#   {'category': 'news_car'},
#   {'category': 'news_sports'},
#   {'category': 'news_entertainment'},
#   {'category': 'news_car'},
#   {'category': 'news_tech'},
#   {'category': 'news_story'},
#   {'category': 'news_tech'},
#   {'category': 'news_game'},
#   {'category': 'news_tech'},
#   {'category': 'news_culture'},
#   {'category': 'news_game'},
#   {'category': 'news_tech'},
#   {'category': 'news_world'},
#   {'category': 'news_agriculture'},
#   {'category': 'news_edu'},
#   {'category': 'news_tech'},
#   {'category': 'news_travel'},
#   {'category': 'news_house'},
#   {'category': 'news_game'},
#   {'category': 'news_game'},
#   {'category': 'news_game'}],
#  [{'news': '马云又出惊人言论，8年后房子最不值钱，他的话可信吗？', 'keywords': nan},
#   {'news': '上联：泰山黄山赵本山，如何对下联？', 'keywords': nan},
#   {'news': '为什么现在没有人玩CS了？', 'keywords': nan},
#   {'news': '京东白条还款逾期了半个月，会影响个人征信吗？', 'keywords': nan},
#   {'news': '库蒂尼奥接受采访时说：“我不想继承梅西的10号球衣”对此，你怎么评价？', 'keywords': nan},
#   {'news': '宝莲灯9月将翻拍，粉丝总结5位经典角色，第3位有人敢接吗？',
#    'keywords': '宝莲灯前传,宝莲灯,小狐狸,寻秦记,沉香,笑傲江湖,二郎神,焦恩俊,亮剑,三圣母'},
#   {'news': '年轻人的设计 “大排量”与省油兼得 这样的日系车不了解一下？',
#    'keywords': 'MINI,B级车,HYBRID,帕萨特,阿特兹,雷克萨斯,凯美瑞,TNGA,马自达,大排量,混动车,卡罗拉,普锐斯,省油,E-CVT,奥迪A3'},
#   {'news': '华为mate9和华为mate9pro哪个好？',
#    'keywords': '机身,华为Mate9,双曲面,Mate9 Pro,华为Mate9 Pro'},
#   {'news': '月薪5000元在北京是什么样的水平？', 'keywords': '月薪,月薪5000,北京,地下室,王二娃'},
#   {'news': '为什么有时候大姨妈会越来越少？', 'keywords': nan},
#   {'news': '12日热点新闻：国产航母来不及沾沾自喜，仍迫切需要提升舰载机支持能力',
#    'keywords': '国产航母,RNG,奥巴马,辽宁舰,特朗普'},
#   {'news': '三星诚意回馈中国消费者，多款旗舰机型迎来夏季狂欢节',
#    'keywords': 'Galaxy S9,手机零售指数,三星Galaxy,迪信通,三星,智能手机'},
#   {'news': '能把孤独写得这样透彻，除了林语堂其他人都做不到', 'keywords': '林语堂,近现代,左与右,中国作家'},
#   {'news': '论音乐的重要性 梦幻西游玩家依靠听歌竟成为全服第一红？',
#    'keywords': '恭喜发财,纯音乐,借我,轻音乐,理想三旬,in the end,今天是个好日子,梦幻西游,定西,雪之梦,开箱子时,好运来,金刚石'},
#   {'news': '“机蜜”全攻略：小米上市在即，酷派为蹭热度不惜自残！', 'keywords': '运营商,小米,贾跃亭,智能机,酷派'},
#   {'news': '伊核协议出现新的转机，特朗普推特发出周二宣布对伊朗协议的决定！',
#    'keywords': '默克尔,伊朗,伊核协议,唐纳德·特朗普,马克龙'},
#   {'news': '五月正吃的营养水果——甜瓜，营养价值高，味道甘甜可口！',
#    'keywords': '甜瓜新鲜,水果,羊角蜜,精选阎良甜瓜,甜香多汁'},
#   {'news': '福利来了 2018年兰州五十四中分校进入九州 并于8月开始招生', 'keywords': '九州,兰州'},
#   {'news': '想学人工智能？不用去新东方，在临颍都能学！', 'keywords': '临颍,机器人,新东方,临颍县,人工智能'},
#   {'news': '旅行带给大家最大的收获是什么？', 'keywords': nan},
#   {'news': '深圳炒房的人现在都怎么样了？套现了吗？', 'keywords': '房产,深圳,炒房客,房价,市场价'},
#   {'news': '你以为我英语8级啊？Steam上急需中文的三款游戏',
#    'keywords': '网络游戏,上古卷轴,策略游戏,Steam平台,汉化'},
#   {'news': 'LOL：FNC自信过头，五人草丛埋伏，Uzi一招吓得敌方水晶爆了！',
#    'keywords': 'FNC,RNG,UZI,MSI,英雄联盟'},
#   {'news': '王者荣耀：一级想安心打buff？捣乱者不去野区搞点事情就太可惜了', 'keywords': '钟馗,在野区,打野,buff'}],
#  [{'category': 'news_house'},
#   {'category': 'news_culture'},
#   {'category': 'news_game'},
#   {'category': 'news_tech'},
#   {'category': 'news_edu'},
#   {'category': 'news_agriculture'},
#   {'category': 'news_military'},
#   {'category': 'news_finance'},
#   {'category': 'news_military'},
#   {'category': 'news_travel'},
#   {'category': 'news_agriculture'},
#   {'category': 'news_game'},
#   {'category': 'news_tech'},
#   {'category': 'news_world'},
#   {'category': 'news_military'},
#   {'category': 'news_edu'},
#   {'category': 'news_sports'},
#   {'category': 'news_finance'},
#   {'category': 'news_entertainment'},
#   {'category': 'news_world'},
#   {'category': 'news_tech'},
#   {'category': 'news_agriculture'},
#   {'category': 'news_agriculture'},
#   {'category': 'news_entertainment'},
#   {'category': 'news_agriculture'},
#   {'category': 'news_story'},
#   {'category': 'news_edu'},
#   {'category': 'news_game'},
#   {'category': 'news_entertainment'},
#   {'category': 'news_car'},
#   {'category': 'news_sports'},
#   {'category': 'news_sports'},
#   {'category': 'news_entertainment'},
#   {'category': 'news_car'},
#   {'category': 'news_culture'},
#   {'category': 'news_story'},
#   {'category': 'news_culture'},
#   {'category': 'news_edu'},
#   {'category': 'news_military'},
#   {'category': 'news_sports'},
#   {'category': 'news_house'},
#   {'category': 'news_game'},
#   {'category': 'news_military'},
#   {'category': 'news_car'},
#   {'category': 'news_finance'},
#   {'category': 'news_military'},
#   {'category': 'news_edu'},
#   {'category': 'news_tech'},
#   {'category': 'news_edu'},
#   {'category': 'news_house'},
#   {'category': 'news_finance'},
#   {'category': 'news_tech'},
#   {'category': 'news_world'},
#   {'category': 'news_entertainment'},
#   {'category': 'news_travel'},
#   {'category': 'news_sports'},
#   {'category': 'news_entertainment'},
#   {'category': 'news_tech'},
#   {'category': 'news_finance'},
#   {'category': 'news_tech'},
#   {'category': 'news_car'},
#   {'category': 'news_game'},
#   {'category': 'news_car'},
#   {'category': 'news_edu'},
#   {'category': 'news_agriculture'},
#   {'category': 'news_car'},
#   {'category': 'news_finance'},
#   {'category': 'news_finance'},
#   {'category': 'news_sports'},
#   {'category': 'news_travel'},
#   {'category': 'news_sports'},
#   {'category': 'news_house'},
#   {'category': 'news_culture'},
#   {'category': 'news_house'},
#   {'category': 'news_game'},
#   {'category': 'news_house'},
#   {'category': 'news_tech'},
#   {'category': 'news_tech'},
#   {'category': 'news_edu'},
#   {'category': 'news_car'},
#   {'category': 'news_sports'},
#   {'category': 'news_entertainment'},
#   {'category': 'news_car'},
#   {'category': 'news_tech'},
#   {'category': 'news_story'},
#   {'category': 'news_tech'},
#   {'category': 'news_game'},
#   {'category': 'news_tech'},
#   {'category': 'news_culture'},
#   {'category': 'news_game'},
#   {'category': 'news_tech'},
#   {'category': 'news_world'},
#   {'category': 'news_agriculture'},
#   {'category': 'news_edu'},
#   {'category': 'news_tech'},
#   {'category': 'news_travel'},
#   {'category': 'news_house'},
#   {'category': 'news_game'},
#   {'category': 'news_game'},
#   {'category': 'news_game'}])

# %%
b=[]
for i in a.iloc[:,3]:
    try:
        b.append(len(i))
    except:
        print("nan")
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
np.median(b)
# Out:
# 20.0

# %%
dataset.processor.id2lael.index('news_story')
# Out:
# 14

# %%
e=dataset.get_all_processor_data()[0]

# %%
e[0][0]
# Out:
# array(['0.110945', '-0.527063', '-0.032127', '-0.063687', '0.081191',
#        '-0.026788', '0.183200', '0.237261', '-0.077282', '0.381939',
#        '0.425551', '-0.285006', '-0.188020', '0.119483', '-0.178870',
#        '-0.208712', '-0.099174', '-0.364492', '0.011476', '0.050310',
#        '-0.159838', '0.275575', '-0.065305', '0.238609', '0.267481',
#        '0.077858', '-0.037049', '-0.005327', '0.442652', '-0.312521',
#        '-0.530788', '-0.382351', '0.265930', '0.455289', '0.264377',
#        '-0.116760', '0.075926', '0.206391', '-0.626972', '0.386602',
#        '0.143892', '0.044298', '0.433043', '-0.244783', '-0.213814',
#        '0.089808', '-0.138743', '-0.529118', '-0.170628', '-0.050924',
#        '-0.211896', '0.154626', '-0.033809', '0.106125', '0.435300',
#        '0.054831', '0.106073', '0.343850', '0.634969', '0.248189',
#        '0.135646', '0.318948', '0.202574', '0.055365', '0.256396',
#        '-0.027521', '-0.043095', '0.272974', '-0.004491', '-0.148166',
#        '-0.780256', '-0.203091', '0.340864', '0.295604', '0.008820',
#        '0.310004', '-0.117896', '-0.012426', '0.037473', '-0.137479',
#        '0.299913', '0.569257', '-0.205771', '0.303026', '0.075871',
#        '0.459476', '-0.329320', '0.072267', '-0.747857', '-0.114902',
#        '-0.312142', '0.114835', '0.102971', '-0.200550', '0.222420',
#        '-0.069696', '0.154547', '0.660317', '-0.123003', '-0.235705',
#        '0.027143', '-0.173151', '-0.266120', '-0.028466', '-0.382115',
#        '0.117084', '0.233459', '-0.254995', '0.141640', '0.334709',
#        '-0.330054', '0.161397', '0.270840', '-0.351221', '0.031090',
#        '0.046403', '0.458992', '0.055388', '-0.089936', '-0.068088',
#        '0.325961', '-0.377419', '-0.325772', '-0.356563', '-0.129336',
#        '0.037980', '0.065406', '-0.087862', '-0.427352', '0.183651',
#        '-0.226085', '-0.050214', '0.174579', '0.389802', '-0.040636',
#        '-0.357771', '0.010837', '-0.263346', '0.544157', '-0.098642',
#        '-0.430137', '-0.360073', '-0.089083', '-0.274148', '-0.218829',
#        '-0.519723', '0.404143', '0.321237', '-0.395050', '-0.037563',
#        '0.230729', '0.018671', '0.138408', '-0.146583', '-0.089275',
#        '-0.177151', '-0.085701', '0.571131', '0.088356', '0.147543',
#        '0.993628', '-0.074236', '0.033761', '0.113981', '0.245439',
#        '0.031062', '0.009958', '0.130943', '0.399623', '-0.367208',
#        '-0.120657', '-0.370956', '0.007062', '0.037949', '0.017649',
#        '-0.028555', '-0.446532', '-0.291845', '0.064561', '0.303120',
#        '-0.344579', '0.170202', '-0.243278', '-0.100259', '0.231587',
#        '0.172152', '-0.366561', '0.448227', '0.068327', '-0.171141',
#        '0.194209', '0.184240', '-0.524403', '0.031975', '0.341468',
#        '0.341737', '-0.140507', '-0.197734', '0.194674', '0.448304\n'],
#       dtype='<U10')

# %%
[len(i) for i in a.iloc[:,3] if i is not 'nan']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-dbd433692893> in <module>
# ----> 1 [len(i) for i in a.iloc[:,3] if i is not 'nan']
#
# <ipython-input-37-dbd433692893> in <listcomp>(.0)
# ----> 1 [len(i) for i in a.iloc[:,3] if i is not 'nan']
#
# TypeError: object of type 'float' has no len()

# %%
[len(i) for i in dataset.get_all_processor_data()]
# Out:
# [100, 100, 100, 100]

# %%
[i.shape for i in dataset.get_all_processor_data()]
# Out:
# [(100, 50, 200), (100, 15), (100, 50, 200), (100, 15)]

# %%
float,dataset.processor.word_embed['内'])

# %%
from flyai.utils.yaml_helper import Yaml

# %%
yaml=Yaml()

# %%
xd = a[yaml.get_input_names()].to_dict(orient='records')

# %%
xd
# Out:
# [{'news': '马云又出惊人言论，8年后房子最不值钱，他的话可信吗？', 'keywords': nan},
#  {'news': 'iPhone 6s有一点问题，耗电很快是为什么？', 'keywords': 'iPhone,iphone 6s'},
#  {'news': '最后一周，0基础通过初级会计职称，就靠这4招秘诀了！',
#   'keywords': '都有为,会计学,了解更多,会计,经济法基础,会计分录,跟着笨笨干会计,零基础学会计,初级会计实务,会计入门全知道'},
#  {'news': '比亚迪再获美国洛杉矶机场20台电动大巴订单，厉害了我的迪！', 'keywords': '比亚迪,洛杉矶,洛杉矶机场,美国'},
#  {'news': '库蒂尼奥接受采访时说：“我不想继承梅西的10号球衣”对此，你怎么评价？', 'keywords': nan},
#  {'news': '宝莲灯9月将翻拍，粉丝总结5位经典角色，第3位有人敢接吗？',
#   'keywords': '宝莲灯前传,宝莲灯,小狐狸,寻秦记,沉香,笑傲江湖,二郎神,焦恩俊,亮剑,三圣母'},
#  {'news': '年轻人的设计 “大排量”与省油兼得 这样的日系车不了解一下？',
#   'keywords': 'MINI,B级车,HYBRID,帕萨特,阿特兹,雷克萨斯,凯美瑞,TNGA,马自达,大排量,混动车,卡罗拉,普锐斯,省油,E-CVT,奥迪A3'},
#  {'news': '华为mate9和华为mate9pro哪个好？',
#   'keywords': '机身,华为Mate9,双曲面,Mate9 Pro,华为Mate9 Pro'},
#  {'news': '月薪5000元在北京是什么样的水平？', 'keywords': '月薪,月薪5000,北京,地下室,王二娃'},
#  {'news': '为什么有时候大姨妈会越来越少？', 'keywords': nan},
#  {'news': '12日热点新闻：国产航母来不及沾沾自喜，仍迫切需要提升舰载机支持能力',
#   'keywords': '国产航母,RNG,奥巴马,辽宁舰,特朗普'},
#  {'news': '三星诚意回馈中国消费者，多款旗舰机型迎来夏季狂欢节',
#   'keywords': 'Galaxy S9,手机零售指数,三星Galaxy,迪信通,三星,智能手机'},
#  {'news': '能把孤独写得这样透彻，除了林语堂其他人都做不到', 'keywords': '林语堂,近现代,左与右,中国作家'},
#  {'news': '论音乐的重要性 梦幻西游玩家依靠听歌竟成为全服第一红？',
#   'keywords': '恭喜发财,纯音乐,借我,轻音乐,理想三旬,in the end,今天是个好日子,梦幻西游,定西,雪之梦,开箱子时,好运来,金刚石'},
#  {'news': '“机蜜”全攻略：小米上市在即，酷派为蹭热度不惜自残！', 'keywords': '运营商,小米,贾跃亭,智能机,酷派'},
#  {'news': '伊核协议出现新的转机，特朗普推特发出周二宣布对伊朗协议的决定！',
#   'keywords': '默克尔,伊朗,伊核协议,唐纳德·特朗普,马克龙'},
#  {'news': '五月正吃的营养水果——甜瓜，营养价值高，味道甘甜可口！',
#   'keywords': '甜瓜新鲜,水果,羊角蜜,精选阎良甜瓜,甜香多汁'},
#  {'news': '福利来了 2018年兰州五十四中分校进入九州 并于8月开始招生', 'keywords': '九州,兰州'},
#  {'news': '想学人工智能？不用去新东方，在临颍都能学！', 'keywords': '临颍,机器人,新东方,临颍县,人工智能'},
#  {'news': '旅行带给大家最大的收获是什么？', 'keywords': nan},
#  {'news': '深圳炒房的人现在都怎么样了？套现了吗？', 'keywords': '房产,深圳,炒房客,房价,市场价'},
#  {'news': '你以为我英语8级啊？Steam上急需中文的三款游戏',
#   'keywords': '网络游戏,上古卷轴,策略游戏,Steam平台,汉化'},
#  {'news': 'LOL：FNC自信过头，五人草丛埋伏，Uzi一招吓得敌方水晶爆了！',
#   'keywords': 'FNC,RNG,UZI,MSI,英雄联盟'},
#  {'news': '王者荣耀：一级想安心打buff？捣乱者不去野区搞点事情就太可惜了', 'keywords': '钟馗,在野区,打野,buff'}]

# %%
a
# Out:
#      id            category                                          news  \
# 0   106          news_house                    马云又出惊人言论，8年后房子最不值钱，他的话可信吗？
# 1   101        news_culture                             上联：泰山黄山赵本山，如何对下联？
# 2   116           news_game                                 为什么现在没有人玩CS了？
# 3   109           news_tech                        京东白条还款逾期了半个月，会影响个人征信吗？
# 4   108            news_edu                                长洲教育大家谈第二期主题公告
# 5   115    news_agriculture                                 脐橙卷叶？原因竟然是这个！
# 6   110       news_military                      这人驾驶技术真好，开着大型轰炸机降落在航空母舰上
# 7   104        news_finance                            马云持股少，但没想到，刘强东持股也少
# 8   110       news_military                       卖军火已成精，飞机便宜给你，后续靠弹药也能赚翻
# 9   112         news_travel                                    山东为什么盛产美男？
# 10  115    news_agriculture                       美好生活，与你同在，5年时间，太原的你离不开它
# 11  116           news_game                       FPS游戏《原子之心》公布 另一条世界线的故事
# 12  109           news_tech                                   谷歌介绍自适应电池功能
# 13  113          news_world                    连奥巴马都忍不了了，猛烈抨击特朗普，还要一意孤行吗？
# 14  110       news_military                          国家宣战权有何用处，不宣而战又会怎么样？
# 15  108            news_edu                                 怎样看待当前地域黑的问题？
# 16  103         news_sports                 不要阿兰不要高拉特！恒大球迷要求回购一人，他让两大名帅后悔
# 17  104        news_finance                             量子点电视将引领高端电视领域新航向
# 18  102  news_entertainment                           赵薇、范冰冰、林心如，你觉得谁最漂亮？
# 19  113          news_world                        伊朗为什么宁愿接受制裁也不同意修改伊核协议？
# 20  109           news_tech            富士康总裁郭台铭放话：未来电商平台可能会消失！你怎么看？马云怎么办？
# 21  115    news_agriculture                                   毛泽东：西江月秋收起义
# 22  115    news_agriculture                            「践行四种人」“消薄增收”我们在行动
# 23  102  news_entertainment                      张钧甯撞衫毛晓彤，网友：妇女和仙女的差距一目了然
# 24  115    news_agriculture                很难得才能碰到的，这种玉米笋比玉米贵4倍，几十斤碰到麻溜买完
# 25  100          news_story                我生女儿，婆婆二话没说打了两巴掌，医生护士却直夸“打得好”！
# 26  108            news_edu                           苏州大学国际班 你可以申请这些特色专业
# 27  116           news_game                       「Steam折扣推荐」兽人必须死系列好价促销！
# 28  102  news_entertainment                易烊千玺亲自为《这就是街舞》队员做了四件事，按摩只是其中之一
# 29  107            news_car                    为什么汽车买黑色和白色的最多？买车应该如何选择颜色？
# ..  ...                 ...                                           ...
# 70  103         news_sports                          幸福满满！福特森晒与妻子海边浪漫度假照片
# 71  106          news_house                       特朗普所做的一切会不会只是为了自己的商业帝国？
# 72  101        news_culture                            上联是：梅香腊月三分雪，如何对下联？
# 73  106          news_house                       马云判断未来房价会便宜如白菜，是基于什么逻辑？
# 74  116           news_game                        MSI季中赛RNG对战KZ时战败，是谁的锅？
# 75  106          news_house                              政策调整 “限价房”可转共有产权
# 76  109           news_tech  声明：Oculus Research正式更名为Facebook Reality Labs
# 77  109           news_tech                      iPhone 6s有一点问题，耗电很快是为什么？
# 78  108            news_edu                    最后一周，0基础通过初级会计职称，就靠这4招秘诀了！
# 79  107            news_car                 比亚迪再获美国洛杉矶机场20台电动大巴订单，厉害了我的迪！
# 80  103         news_sports           库蒂尼奥接受采访时说：“我不想继承梅西的10号球衣”对此，你怎么评价？
# 81  102  news_entertainment                 宝莲灯9月将翻拍，粉丝总结5位经典角色，第3位有人敢接吗？
# 82  107            news_car                年轻人的设计 “大排量”与省油兼得 这样的日系车不了解一下？
# 83  109           news_tech                        华为mate9和华为mate9pro哪个好？
# 84  100          news_story                            月薪5000元在北京是什么样的水平？
# 85  109           news_tech                               为什么有时候大姨妈会越来越少？
# 86  116           news_game            12日热点新闻：国产航母来不及沾沾自喜，仍迫切需要提升舰载机支持能力
# 87  109           news_tech                     三星诚意回馈中国消费者，多款旗舰机型迎来夏季狂欢节
# 88  101        news_culture                       能把孤独写得这样透彻，除了林语堂其他人都做不到
# 89  116           news_game                   论音乐的重要性 梦幻西游玩家依靠听歌竟成为全服第一红？
# 90  109           news_tech                    “机蜜”全攻略：小米上市在即，酷派为蹭热度不惜自残！
# 91  113          news_world               伊核协议出现新的转机，特朗普推特发出周二宣布对伊朗协议的决定！
# 92  115    news_agriculture                   五月正吃的营养水果——甜瓜，营养价值高，味道甘甜可口！
# 93  108            news_edu               福利来了 2018年兰州五十四中分校进入九州 并于8月开始招生
# 94  109           news_tech                         想学人工智能？不用去新东方，在临颍都能学！
# 95  112         news_travel                               旅行带给大家最大的收获是什么？
# 96  106          news_house                           深圳炒房的人现在都怎么样了？套现了吗？
# 97  116           news_game                     你以为我英语8级啊？Steam上急需中文的三款游戏
# 98  116           news_game             LOL：FNC自信过头，五人草丛埋伏，Uzi一招吓得敌方水晶爆了！
# 99  116           news_game              王者荣耀：一级想安心打buff？捣乱者不去野区搞点事情就太可惜了
#
#                                              keywords
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                       社会主义,长洲教育大家谈,长洲,核心价值观,核心价值观融入
# 5                                   卷叶,脐橙,线虫,脐橙卷叶,脐橙卷
# 6                                            轰炸机,航空母舰
# 7                                刘强东,京东集团,阿里巴巴,蔡崇信,马云
# 8                   彩虹-5,中航工业,中国北方工业公司,MBDA,EF2000,弹药
# 9                                                 NaN
# 10                                         同城,58同城,太原
# 11                 FPS游戏,原子之心,传奇,全民捕鱼赢话费,机器人,太平洋,口袋妖怪
# 12                            马斯洛,WiFi,自适应电池功能,谷歌,CPU
# 13                                伊朗核协议,特朗普,共和党,美国,盟友
# 14                            缔约国,不宣而战,自卫队,宣战权,日内瓦四公约
# 15                                                NaN
# 16                              金英权,高拉特,卡纳瓦罗,中超联赛,穆里奇
# 17                           高端产品,量子点,量子点电视,消费升级,彩电产品
# 18                                                NaN
# 19                                                NaN
# 20                         用户端,电子商务,阿里巴巴,实体经济,马云,电商平台
# 21                                           秋收起义,毛泽东
# 22                                桃源村,洪家村,浪川乡,消薄增收,农村
# 23                                     连衣裙,仙女,张钧甯,毛晓彤
# 24                                             玉米笋,玉米
# 25                                     婴儿,内容无关,女孩儿,医生
# 26                            国际班,艺术设计,酒店管理,旅游管理,苏州大学
# 27                          游戏,Warrior,Die,Must,豪华版享受
# 28                      一个舞者,这就是街舞,清洁工,易烊千玺,舞蹈,千玺,话筒架
# 29                                                NaN
# ..                                                ...
# 70                                     福特森,广厦队,福特,考特尼
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                         共有产权住房,保障房,限房价项目,评估价,共有产权房
# 76                      Labs,Facebook,材料科学,实验室,Oculus
# 77                                   iPhone,iphone 6s
# 78  都有为,会计学,了解更多,会计,经济法基础,会计分录,跟着笨笨干会计,零基础学会计,初级会计...
# 79                                   比亚迪,洛杉矶,洛杉矶机场,美国
# 80                                                NaN
# 81           宝莲灯前传,宝莲灯,小狐狸,寻秦记,沉香,笑傲江湖,二郎神,焦恩俊,亮剑,三圣母
# 82  MINI,B级车,HYBRID,帕萨特,阿特兹,雷克萨斯,凯美瑞,TNGA,马自达,大排量,...
# 83               机身,华为Mate9,双曲面,Mate9 Pro,华为Mate9 Pro
# 84                               月薪,月薪5000,北京,地下室,王二娃
# 85                                                NaN
# 86                               国产航母,RNG,奥巴马,辽宁舰,特朗普
# 87              Galaxy S9,手机零售指数,三星Galaxy,迪信通,三星,智能手机
# 88                                   林语堂,近现代,左与右,中国作家
# 89  恭喜发财,纯音乐,借我,轻音乐,理想三旬,in the end,今天是个好日子,梦幻西游,定...
# 90                                  运营商,小米,贾跃亭,智能机,酷派
# 91                            默克尔,伊朗,伊核协议,唐纳德·特朗普,马克龙
# 92                            甜瓜新鲜,水果,羊角蜜,精选阎良甜瓜,甜香多汁
# 93                                              九州,兰州
# 94                                临颍,机器人,新东方,临颍县,人工智能
# 95                                                NaN
# 96                                   房产,深圳,炒房客,房价,市场价
# 97                          网络游戏,上古卷轴,策略游戏,Steam平台,汉化
# 98                               FNC,RNG,UZI,MSI,英雄联盟
# 99                                     钟馗,在野区,打野,buff
#
# [100 rows x 4 columns]

# %%
a[['news','keywords']]
# Out:
#                                             news  \
# 0                     马云又出惊人言论，8年后房子最不值钱，他的话可信吗？
# 1                              上联：泰山黄山赵本山，如何对下联？
# 2                                  为什么现在没有人玩CS了？
# 3                         京东白条还款逾期了半个月，会影响个人征信吗？
# 4                                 长洲教育大家谈第二期主题公告
# 5                                  脐橙卷叶？原因竟然是这个！
# 6                       这人驾驶技术真好，开着大型轰炸机降落在航空母舰上
# 7                             马云持股少，但没想到，刘强东持股也少
# 8                        卖军火已成精，飞机便宜给你，后续靠弹药也能赚翻
# 9                                     山东为什么盛产美男？
# 10                       美好生活，与你同在，5年时间，太原的你离不开它
# 11                       FPS游戏《原子之心》公布 另一条世界线的故事
# 12                                   谷歌介绍自适应电池功能
# 13                    连奥巴马都忍不了了，猛烈抨击特朗普，还要一意孤行吗？
# 14                          国家宣战权有何用处，不宣而战又会怎么样？
# 15                                 怎样看待当前地域黑的问题？
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                       社会主义,长洲教育大家谈,长洲,核心价值观,核心价值观融入
# 5                                   卷叶,脐橙,线虫,脐橙卷叶,脐橙卷
# 6                                            轰炸机,航空母舰
# 7                                刘强东,京东集团,阿里巴巴,蔡崇信,马云
# 8                   彩虹-5,中航工业,中国北方工业公司,MBDA,EF2000,弹药
# 9                                                 NaN
# 10                                         同城,58同城,太原
# 11                 FPS游戏,原子之心,传奇,全民捕鱼赢话费,机器人,太平洋,口袋妖怪
# 12                            马斯洛,WiFi,自适应电池功能,谷歌,CPU
# 13                                伊朗核协议,特朗普,共和党,美国,盟友
# 14                            缔约国,不宣而战,自卫队,宣战权,日内瓦四公约
# 15                                                NaN
# 16                              金英权,高拉特,卡纳瓦罗,中超联赛,穆里奇
# 17                           高端产品,量子点,量子点电视,消费升级,彩电产品
# 18                                                NaN
# 19                                                NaN
# 20                         用户端,电子商务,阿里巴巴,实体经济,马云,电商平台
# 21                                           秋收起义,毛泽东
# 22                                桃源村,洪家村,浪川乡,消薄增收,农村
# 23                                     连衣裙,仙女,张钧甯,毛晓彤
# 24                                             玉米笋,玉米
# 25                                     婴儿,内容无关,女孩儿,医生
# 26                            国际班,艺术设计,酒店管理,旅游管理,苏州大学
# 27                          游戏,Warrior,Die,Must,豪华版享受
# 28                      一个舞者,这就是街舞,清洁工,易烊千玺,舞蹈,千玺,话筒架
# 29                                                NaN
# ..                                                ...
# 70                                     福特森,广厦队,福特,考特尼
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                         共有产权住房,保障房,限房价项目,评估价,共有产权房
# 76                      Labs,Facebook,材料科学,实验室,Oculus
# 77                                   iPhone,iphone 6s
# 78  都有为,会计学,了解更多,会计,经济法基础,会计分录,跟着笨笨干会计,零基础学会计,初级会计...
# 79                                   比亚迪,洛杉矶,洛杉矶机场,美国
# 80                                                NaN
# 81           宝莲灯前传,宝莲灯,小狐狸,寻秦记,沉香,笑傲江湖,二郎神,焦恩俊,亮剑,三圣母
# 82  MINI,B级车,HYBRID,帕萨特,阿特兹,雷克萨斯,凯美瑞,TNGA,马自达,大排量,...
# 83               机身,华为Mate9,双曲面,Mate9 Pro,华为Mate9 Pro
# 84                               月薪,月薪5000,北京,地下室,王二娃
# 85                                                NaN
# 86                               国产航母,RNG,奥巴马,辽宁舰,特朗普
# 87              Galaxy S9,手机零售指数,三星Galaxy,迪信通,三星,智能手机
# 88                                   林语堂,近现代,左与右,中国作家
# 89  恭喜发财,纯音乐,借我,轻音乐,理想三旬,in the end,今天是个好日子,梦幻西游,定...
# 90                                  运营商,小米,贾跃亭,智能机,酷派
# 91                            默克尔,伊朗,伊核协议,唐纳德·特朗普,马克龙
# 92                            甜瓜新鲜,水果,羊角蜜,精选阎良甜瓜,甜香多汁
# 93                                              九州,兰州
# 94                                临颍,机器人,新东方,临颍县,人工智能
# 95                                                NaN
# 96                                   房产,深圳,炒房客,房价,市场价
# 97                          网络游戏,上古卷轴,策略游戏,Steam平台,汉化
# 98                               FNC,RNG,UZI,MSI,英雄联盟
# 99                                     钟馗,在野区,打野,buff
#
# [100 rows x 2 columns]

# %%
dataset.db.source.get_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-97feaa6b4b1b> in <module>
# ----> 1 dataset.db.source.get_data()
#
# TypeError: get_data() missing 1 required positional argument: 'data'

# %%
'内' in dataset.processor.word_embed.keys()
# Out:
# True

# %%
dataset

# %%
for j in range(50-60):
    print(j)

# %%
import numpy as np

# %%
[[1,1,1],[2,2,2]]+[[3,3,3]]
# Out:
# [[1, 1, 1], [2, 2, 2], [3, 3, 3]]

# %%
# 超参
parser = argparse.ArgumentParser()
parser.add_argument("-e", "--EPOCHS", default=20, type=int, help="train epochs")
parser.add_argument("-b", "--BATCH", default=32, type=int, help="batch size")
args = parser.parse_args([])
max_seq_len = 50
'''
使用tensorflow实现自己的算法

'''

# 得到训练和测试的数据
# batch_size=100
time_step = 5  # lstm序列长度
input_size = 200

rnn_unit = 200  # hidden layer units

output_size = 15
lr = 0.0006  # 学习率
# ——————————————————导入数据——————————————————————

input_x = tf.placeholder(tf.float32, shape=[None, max_seq_len, input_size], name="input_x")
input_y = tf.placeholder(tf.float32, shape=[None, output_size], name="input_y")
keep_prob = tf.placeholder(tf.float32, name='keep_prob')

# ——————————————————定义神经网络变量——————————————————
# 输入层、输出层权重、偏置

# with tf.variable_scope('in_out',reuse=tf.AUTO_REUSE):
weights = {
    'out': tf.Variable(tf.random_normal([2 * max_seq_len * rnn_unit, 15]))
}
biases = {
    'out': tf.Variable(tf.constant(0.1, shape=[15, ]))
}


# ——————————————————定义神经网络变量——————————————————
def lstm(X):
    #    with tf.variable_scope('lstm',reuse=tf.AUTO_REUSE):
    input_rnn = tf.reshape(X, [-1, max_seq_len, rnn_unit])  # 将tensor转成3维，作为lstm cell的输入
    s = tf.shape(input_rnn)
    # bi lstm on words
    cell_fw = tf.contrib.rnn.LSTMCell(rnn_unit,
                                      state_is_tuple=True)
    cell_bw = tf.contrib.rnn.LSTMCell(rnn_unit,
                                      state_is_tuple=True)
    outputs, states = tf.nn.bidirectional_dynamic_rnn(
        cell_fw, cell_bw, input_rnn,
        dtype=tf.float32)
    output_fw, output_bw = outputs
    states_fw, states_bw = states
    # read and concat output
    output_word = tf.concat([output_fw, output_bw], axis=-1)

    # shape = (batch size, max sentence length, char hidden size)
    output_w = tf.reshape(output_word,
                          shape=[s[0], s[1], 2 * rnn_unit])

    output = tf.reshape(output_w, [-1, 2 * max_seq_len * rnn_unit])  # 作为输出层的输入
    w_out = weights['out']
    b_out = biases['out']
    pred = tf.add(tf.matmul(output, w_out), b_out, name="pre")
    return pred


# ——————————————————训练模型——————————————————

# with tf.variable_scope('pre',reuse=tf.AUTO_REUSE):
y = lstm(input_x)
y_conv = tf.argmax(y, name="y_conv", axis=1)

# # 损失函数
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=y, labels=input_y, name=None))
#
train_op = tf.train.AdamOptimizer(lr).minimize(loss)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(args.EPOCHS):
        x_train, y_train, x_test, y_test = dataset.next_batch(args.BATCH)
        #        y = sess.run(y_conv, feed_dict={input_x: x_train})
        sess.run(train_op, feed_dict={input_x: x_train, input_y: y_train})
        loss_ = sess.run(loss, feed_dict={input_x: x_train, input_y: y_train})
        print('loss:', loss_)

    model.save_model(sess, MODEL_PATH, overwrite=True)
