# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %% [markdown]
# ## read flyai data for vision task

# %%
path_root = Path('../vision/PlantSeedlingsClassification_FlyAI/')
path_train = path_root/'data/local/train'
path_test = path_root/'data/local/test'
path_train.ls(),path_test.ls()
# Out:
# ([PosixPath('../vision/PlantSeedlingsClassification_FlyAI/data/local/train/train.csv'),
#   PosixPath('../vision/PlantSeedlingsClassification_FlyAI/data/local/train/img')],
#  [PosixPath('../vision/PlantSeedlingsClassification_FlyAI/data/local/test/test.csv'),
#   PosixPath('../vision/PlantSeedlingsClassification_FlyAI/data/local/test/img')])

# %%
trn_csv = pd.read_csv(path_train/'train.csv')
val_csv = pd.read_csv(path_test/'test.csv')
trn_csv.head(),val_csv.head()
# Out:
# (                path                   seedling
#  0  img/163c13912.png                Black-grass
#  1  img/1e0caafd3.png                   Cleavers
#  2  img/19ae90c5c.png  Small-flowered Cranesbill
#  3  img/455546801.png                Black-grass
#  4  img/c0fd4e4aa.png           Common Chickweed,
#                  path           seedling
#  0  img/af98e2c11.png   Common Chickweed
#  1  img/d89fa34ab.png   Loose Silky-bent
#  2  img/5f5015641.png            Fat Hen
#  3  img/8c742310c.png  Scentless Mayweed
#  4  img/b2b62db50.png   Loose Silky-bent)

# %%
data=ImageDataBunch.from_df(path=path_train,df=trn_csv,ds_tfms=get_transforms(),size=224,bs=64,valid_pct=0).normalize(imagenet_stats)
data_val=ImageDataBunch.from_df(path=path_test,df=val_csv,ds_tfms=get_transforms(),size=224,bs=64,valid_pct=0).normalize(imagenet_stats)
data.valid_dl= data_val.train_dl
data
# Out:
# ImageDataBunch;
#
# Train: LabelList
# y: CategoryList (2850 items)
# [Category Black-grass, Category Cleavers, Category Small-flowered Cranesbill, Category Black-grass, Category Common Chickweed]...
# Path: ../vision/PlantSeedlingsClassification_FlyAI/data/local/train
# x: ImageItemList (2850 items)
# [Image (3, 511, 511), Image (3, 103, 103), Image (3, 165, 165), Image (3, 900, 900), Image (3, 173, 173)]...
# Path: ../vision/PlantSeedlingsClassification_FlyAI/data/local/train;
#
# Valid: LabelList
# y: CategoryList (950 items)
# [Category Common Chickweed, Category Loose Silky-bent, Category Fat Hen, Category Scentless Mayweed, Category Loose Silky-bent]...
# Path: ../vision/PlantSeedlingsClassification_FlyAI/data/local/test
# x: ImageItemList (950 items)
# [Image (3, 119, 119), Image (3, 93, 93), Image (3, 307, 307), Image (3, 109, 109), Image (3, 174, 174)]...
# Path: ../vision/PlantSeedlingsClassification_FlyAI/data/local/test;
#
# Test: None

# %%
data.show_batch(rows=3,figsize=(7,6))

# %%
print(data.classes)
# Out:
# ['Black-grass', 'Charlock', 'Cleavers', 'Common Chickweed', 'Common wheat', 'Fat Hen', 'Loose Silky-bent', 'Maize', 'Scentless Mayweed', 'Shepherds Purse', 'Small-flowered Cranesbill', 'Sugar beet']

# %%
@dataclass
class Fbeta_binary(Callback):
    "Computes the fbeta between preds and targets for single-label classification"
    beta2: int = 2
    eps: float = 1e-9
    clas:int=1
    
    def on_epoch_begin(self, **kwargs):
        self.TP = 0
        self.total_y_pred = 0   
        self.total_y_true = 0
    
    def on_batch_end(self, last_output, last_target, **kwargs):
        y_pred = last_output.argmax(dim=1)
        y_true = last_target.float()
        
        self.TP += ((y_pred==self.clas) * (y_true==self.clas)).float().sum()
        self.total_y_pred += (y_pred==self.clas).float().sum()
        self.total_y_true += (y_true==self.clas).float().sum()
    
    def on_epoch_end(self, **kwargs):
        beta2=self.beta2**2
        prec = self.TP/(self.total_y_pred+self.eps)
        rec = self.TP/(self.total_y_true+self.eps)       
        res = (prec*rec)/(prec*beta2+rec+self.eps)*(1+beta2)
        self.metric = res

# %%
from learner import model_meta

# %%
model_meta
# Out:
# {<function torchvision.models.resnet.resnet18(pretrained=False, **kwargs)>: {'cut': -2,
#   'split': <function learner._resnet_split(m:torch.nn.modules.module.Module)>},
#  <function torchvision.models.resnet.resnet34(pretrained=False, **kwargs)>: {'cut': -2,
#   'split': <function learner._resnet_split(m:torch.nn.modules.module.Module)>},
#  <function torchvision.models.resnet.resnet50(pretrained=False, **kwargs)>: {'cut': -2,
#   'split': <function learner._resnet_split(m:torch.nn.modules.module.Module)>},
#  <function torchvision.models.resnet.resnet101(pretrained=False, **kwargs)>: {'cut': -2,
#   'split': <function learner._resnet_split(m:torch.nn.modules.module.Module)>},
#  <function torchvision.models.resnet.resnet152(pretrained=False, **kwargs)>: {'cut': -2,
#   'split': <function learner._resnet_split(m:torch.nn.modules.module.Module)>},
#  <function torchvision.models.squeezenet.squeezenet1_0(pretrained=False, **kwargs)>: {'cut': -1,
#   'split': <function learner._squeezenet_split(m:torch.nn.modules.module.Module)>},
#  <function torchvision.models.squeezenet.squeezenet1_1(pretrained=False, **kwargs)>: {'cut': -1,
#   'split': <function learner._squeezenet_split(m:torch.nn.modules.module.Module)>},
#  <function torchvision.models.densenet.densenet121(pretrained=False, **kwargs)>: {'cut': -1,
#   'split': <function learner._densenet_split(m:torch.nn.modules.module.Module)>},
#  <function torchvision.models.densenet.densenet169(pretrained=False, **kwargs)>: {'cut': -1,
#   'split': <function learner._densenet_split(m:torch.nn.modules.module.Module)>},
#  <function torchvision.models.densenet.densenet201(pretrained=False, **kwargs)>: {'cut': -1,
#   'split': <function learner._densenet_split(m:torch.nn.modules.module.Module)>},
#  <function torchvision.models.densenet.densenet161(pretrained=False, **kwargs)>: {'cut': -1,
#   'split': <function learner._densenet_split(m:torch.nn.modules.module.Module)>},
#  <function torchvision.models.vgg.vgg16_bn(pretrained=False, **kwargs)>: {'cut': -1,
#   'split': <function learner._vgg_split(m:torch.nn.modules.module.Module)>},
#  <function torchvision.models.vgg.vgg19_bn(pretrained=False, **kwargs)>: {'cut': -1,
#   'split': <function learner._vgg_split(m:torch.nn.modules.module.Module)>},
#  <function torchvision.models.alexnet.alexnet(pretrained=False, **kwargs)>: {'cut': -1,
#   'split': <function learner._alexnet_split(m:torch.nn.modules.module.Module)>}}

# %%
for m in list(model_meta.keys()):
    print(m)#learn = None
    try:
        gc.collect()
        torch.cuda.empty_cache()
        learn = create_cnn(data,m,metrics = [error_rate,accuracy, Fbeta_binary(beta2=1,clas = 1)])
        learn.fit_one_cycle(4)
    except:
        print('too many parameters')
# Out:
# <function resnet18 at 0x7f3e40812d90>
# Total time: 00:49 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>2.111534</th>
#     <th>1.091852</th>
#     <th>0.328125</th>
#     <th>0.671875</th>
#     <th>0.741722</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.334934</th>
#     <th>0.659605</th>
#     <th>0.218750</th>
#     <th>0.781250</th>
#     <th>0.875817</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.958950</th>
#     <th>0.529493</th>
#     <th>0.177455</th>
#     <th>0.822545</th>
#     <th>0.896552</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.748559</th>
#     <th>0.538786</th>
#     <th>0.187500</th>
#     <th>0.812500</th>
#     <th>0.906667</th>
#   </tr>
# </table>
# <function resnet34 at 0x7f3e407a6268>
# Total time: 00:53 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>2.055648</th>
#     <th>0.962370</th>
#     <th>0.340402</th>
#     <th>0.659598</th>
#     <th>0.764331</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.261020</th>
#     <th>0.541490</th>
#     <th>0.189732</th>
#     <th>0.810268</th>
#     <th>0.901408</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.873321</th>
#     <th>0.454185</th>
#     <th>0.150670</th>
#     <th>0.849330</th>
#     <th>0.900000</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.667299</th>
#     <th>0.430029</th>
#     <th>0.148438</th>
#     <th>0.851562</th>
#     <th>0.909091</th>
#   </tr>
# </table>
# <function resnet50 at 0x7f3e407a62f0>
# Total time: 01:09 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.590524</th>
#     <th>0.716286</th>
#     <th>0.228795</th>
#     <th>0.771205</th>
#     <th>0.887417</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.933563</th>
#     <th>0.417420</th>
#     <th>0.141741</th>
#     <th>0.858259</th>
#     <th>0.950355</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.607704</th>
#     <th>0.339944</th>
#     <th>0.128348</th>
#     <th>0.871652</th>
#     <th>0.958904</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.442827</th>
#     <th>0.319264</th>
#     <th>0.107143</th>
#     <th>0.892857</th>
#     <th>0.972603</th>
#   </tr>
# </table>
# <function resnet101 at 0x7f3e407a6378>
# Total time: 01:39 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.551033</th>
#     <th>0.605073</th>
#     <th>0.213170</th>
#     <th>0.786830</th>
#     <th>0.840764</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.832940</th>
#     <th>0.340448</th>
#     <th>0.116071</th>
#     <th>0.883929</th>
#     <th>0.960000</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.525631</th>
#     <th>0.287370</th>
#     <th>0.104911</th>
#     <th>0.895089</th>
#     <th>0.970588</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.370506</th>
#     <th>0.296418</th>
#     <th>0.099330</th>
#     <th>0.900670</th>
#     <th>0.965986</th>
#   </tr>
# </table>
# <function resnet152 at 0x7f3e407a6400>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/4 00:00<00:00]
#     </div>
#
# <table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='44', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# too many parameters
# <function squeezenet1_0 at 0x7f3e407a6ae8>
# /home/changebio/anaconda3/envs/fastv1/lib/python3.6/site-packages/torchvision/models/squeezenet.py:94: UserWarning: nn.init.kaiming_uniform is now deprecated in favor of nn.init.kaiming_uniform_.
#   init.kaiming_uniform(m.weight.data)
# /home/changebio/anaconda3/envs/fastv1/lib/python3.6/site-packages/torchvision/models/squeezenet.py:92: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   init.normal(m.weight.data, mean=0.0, std=0.01)
# Total time: 00:48 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.953833</th>
#     <th>1.041459</th>
#     <th>0.345982</th>
#     <th>0.654018</th>
#     <th>0.751773</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.284484</th>
#     <th>0.652514</th>
#     <th>0.214286</th>
#     <th>0.785714</th>
#     <th>0.930556</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.936623</th>
#     <th>0.587080</th>
#     <th>0.203125</th>
#     <th>0.796875</th>
#     <th>0.885714</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.750402</th>
#     <th>0.549802</th>
#     <th>0.189732</th>
#     <th>0.810268</th>
#     <th>0.897959</th>
#   </tr>
# </table>
# <function squeezenet1_1 at 0x7f3e407a6d90>
# Total time: 00:48 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.939681</th>
#     <th>1.044655</th>
#     <th>0.366071</th>
#     <th>0.633929</th>
#     <th>0.717241</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.261862</th>
#     <th>0.704533</th>
#     <th>0.247768</th>
#     <th>0.752232</th>
#     <th>0.869565</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.962833</th>
#     <th>0.602316</th>
#     <th>0.196429</th>
#     <th>0.803571</th>
#     <th>0.925170</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.781083</th>
#     <th>0.569743</th>
#     <th>0.194196</th>
#     <th>0.805804</th>
#     <th>0.898551</th>
#   </tr>
# </table>
# <function densenet121 at 0x7f3e407b2bf8>
# /home/changebio/anaconda3/envs/fastv1/lib/python3.6/site-packages/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# Total time: 01:16 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.736597</th>
#     <th>0.825552</th>
#     <th>0.245536</th>
#     <th>0.754464</th>
#     <th>0.871429</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.948670</th>
#     <th>0.405167</th>
#     <th>0.123884</th>
#     <th>0.876116</th>
#     <th>0.979021</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.580865</th>
#     <th>0.307066</th>
#     <th>0.102679</th>
#     <th>0.897321</th>
#     <th>0.992908</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.407002</th>
#     <th>0.277220</th>
#     <th>0.094866</th>
#     <th>0.905134</th>
#     <th>0.986301</th>
#   </tr>
# </table>
# <function densenet169 at 0x7f3e407b2c80>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/4 00:00<00:00]
#     </div>
#
# <table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='44', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# too many parameters
# <function densenet201 at 0x7f3e407b2d08>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/4 00:00<00:00]
#     </div>
#
# <table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='44', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# too many parameters
# <function densenet161 at 0x7f3e407b2d90>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/4 00:00<00:00]
#     </div>
#
# <table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='44', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# too many parameters
# <function vgg16_bn at 0x7f3e407a6950>
# Total time: 01:33 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>2.085959</th>
#     <th>1.154827</th>
#     <th>0.347098</th>
#     <th>0.652902</th>
#     <th>0.818182</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.274722</th>
#     <th>0.550416</th>
#     <th>0.184152</th>
#     <th>0.815848</th>
#     <th>0.917197</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.856693</th>
#     <th>0.464343</th>
#     <th>0.149554</th>
#     <th>0.850446</th>
#     <th>0.940397</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.655270</th>
#     <th>0.430932</th>
#     <th>0.141741</th>
#     <th>0.858259</th>
#     <th>0.934211</th>
#   </tr>
# </table>
# <function vgg19_bn at 0x7f3e407a6a60>
# Total time: 01:43 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>2.037716</th>
#     <th>1.091339</th>
#     <th>0.341518</th>
#     <th>0.658482</th>
#     <th>0.768212</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.245656</th>
#     <th>0.556614</th>
#     <th>0.196429</th>
#     <th>0.803571</th>
#     <th>0.923077</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.846557</th>
#     <th>0.453369</th>
#     <th>0.156250</th>
#     <th>0.843750</th>
#     <th>0.949640</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.645012</th>
#     <th>0.448933</th>
#     <th>0.168527</th>
#     <th>0.831473</th>
#     <th>0.943662</th>
#   </tr>
# </table>
# <function alexnet at 0x7f3e408128c8>
# Total time: 00:47 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>2.273200</th>
#     <th>1.401725</th>
#     <th>0.454241</th>
#     <th>0.545759</th>
#     <th>0.675159</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.583239</th>
#     <th>0.937740</th>
#     <th>0.315848</th>
#     <th>0.684152</th>
#     <th>0.791045</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>1.237444</th>
#     <th>0.813291</th>
#     <th>0.260045</th>
#     <th>0.739955</th>
#     <th>0.805369</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>1.050631</th>
#     <th>0.808604</th>
#     <th>0.267857</th>
#     <th>0.732143</th>
#     <th>0.820513</th>
#   </tr>
# </table>

# %%
from scipy.io import wavfile

# %%
sr,y = wavfile.read("../speech/UrbanSoundClassification_FlyAI/data/input/wav/104.wav",)

# %%
# ?wavfile.read

# %%
for m in list(model_meta.keys())[5:]:
    #learn = None
    torch.cuda.empty_cache()
    learn = create_cnn(data,m,metrics = [error_rate,accuracy, Fbeta_binary(beta2=1,clas = 1)])
    res=learn.fit_one_cycle(4)
# Out:
# Total time: 01:30 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.226623</th>
#     <th>0.187498</th>
#     <th>0.067769</th>
#     <th>0.932231</th>
#     <th>0.929715</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.215413</th>
#     <th>0.167546</th>
#     <th>0.060683</th>
#     <th>0.939317</th>
#     <th>0.938399</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.174425</th>
#     <th>0.161622</th>
#     <th>0.060138</th>
#     <th>0.939862</th>
#     <th>0.938373</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.181529</th>
#     <th>0.159999</th>
#     <th>0.055778</th>
#     <th>0.944222</th>
#     <th>0.942905</th>
#   </tr>
# </table>
# Downloading: "https://download.pytorch.org/models/squeezenet1_1-f364aa15.pth" to /home/changebio/.torch/models/squeezenet1_1-f364aa15.pth
# 100%|██████████| 4966400/4966400 [00:03<00:00, 1387441.76it/s]
# Total time: 01:25 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.235650</th>
#     <th>0.192989</th>
#     <th>0.065225</th>
#     <th>0.934775</th>
#     <th>0.932251</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.181064</th>
#     <th>0.162079</th>
#     <th>0.058866</th>
#     <th>0.941134</th>
#     <th>0.939303</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.182070</th>
#     <th>0.155746</th>
#     <th>0.055959</th>
#     <th>0.944041</th>
#     <th>0.942857</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.176380</th>
#     <th>0.159411</th>
#     <th>0.058321</th>
#     <th>0.941679</th>
#     <th>0.939008</th>
#   </tr>
# </table>
# /home/changebio/anaconda3/envs/fastv1/lib/python3.6/site-packages/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# Total time: 05:43 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.202340</th>
#     <th>0.157076</th>
#     <th>0.051054</th>
#     <th>0.948946</th>
#     <th>0.947799</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.156629</th>
#     <th>0.136281</th>
#     <th>0.048874</th>
#     <th>0.951126</th>
#     <th>0.950065</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.134919</th>
#     <th>0.122245</th>
#     <th>0.045422</th>
#     <th>0.954578</th>
#     <th>0.953306</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.117643</th>
#     <th>0.115205</th>
#     <th>0.042696</th>
#     <th>0.957304</th>
#     <th>0.956376</th>
#   </tr>
# </table>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/4 00:00<00:00]
#     </div>
#
# <table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='258', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-23-c00a05416676> in <module>
#       3     torch.cuda.empty_cache()
#       4     learn = create_cnn(data,m,metrics = [error_rate,accuracy, Fbeta_binary(beta2=1,clas = 1)])
# ----> 5     res=learn.fit_one_cycle(4)
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, wd, callbacks, **kwargs)
#      20     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor,
#      21                                         pct_start=pct_start, **kwargs))
# ---> 22     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      23
#      24 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, **kwargs:Any):
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     170         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#     171         fit(epochs, self.model, self.loss_func, opt=self.opt, data=self.data, metrics=self.metrics,
# --> 172             callbacks=self.callbacks+callbacks)
#     173
#     174     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, model, loss_func, opt, data, callbacks, metrics)
#      92     except Exception as e:
#      93         exception = e
# ---> 94         raise e
#      95     finally: cb_handler.on_train_end(exception)
#      96
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, model, loss_func, opt, data, callbacks, metrics)
#      82             for xb,yb in progress_bar(data.train_dl, parent=pbar):
#      83                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# ---> 84                 loss = loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      85                 if cb_handler.on_batch_end(loss): break
#      86
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      16     if not is_listy(xb): xb = [xb]
#      17     if not is_listy(yb): yb = [yb]
# ---> 18     out = model(*xb)
#      19     out = cb_handler.on_loss_begin(out)
#      20
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torchvision/models/densenet.py in forward(self, x)
#     139
#     140     def forward(self, x):
# --> 141         new_features = super(_DenseLayer, self).forward(x)
#     142         if self.drop_rate > 0:
#     143             new_features = F.dropout(new_features, p=self.drop_rate, training=self.training)
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     318     def forward(self, input):
#     319         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 320                         self.padding, self.dilation, self.groups)
#     321
#     322
#
# RuntimeError: CUDA out of memory. Tried to allocate 117.50 MiB (GPU 0; 10.91 GiB total capacity; 9.21 GiB already allocated; 142.06 MiB free; 29.96 MiB cached)

# %%
list(model_meta.keys())
# Out:
# [<function torchvision.models.resnet.resnet18(pretrained=False, **kwargs)>,
#  <function torchvision.models.resnet.resnet34(pretrained=False, **kwargs)>,
#  <function torchvision.models.resnet.resnet50(pretrained=False, **kwargs)>,
#  <function torchvision.models.resnet.resnet101(pretrained=False, **kwargs)>,
#  <function torchvision.models.resnet.resnet152(pretrained=False, **kwargs)>,
#  <function torchvision.models.squeezenet.squeezenet1_0(pretrained=False, **kwargs)>,
#  <function torchvision.models.squeezenet.squeezenet1_1(pretrained=False, **kwargs)>,
#  <function torchvision.models.densenet.densenet121(pretrained=False, **kwargs)>,
#  <function torchvision.models.densenet.densenet169(pretrained=False, **kwargs)>,
#  <function torchvision.models.densenet.densenet201(pretrained=False, **kwargs)>,
#  <function torchvision.models.densenet.densenet161(pretrained=False, **kwargs)>,
#  <function torchvision.models.vgg.vgg16_bn(pretrained=False, **kwargs)>,
#  <function torchvision.models.vgg.vgg19_bn(pretrained=False, **kwargs)>,
#  <function torchvision.models.alexnet.alexnet(pretrained=False, **kwargs)>]

# %%
for m in model_meta.keys():
    learn = create_cnn(data,m,metrics = [error_rate,accuracy, Fbeta_binary(beta2=1,clas = 1)])
    res=learn.fit_one_cycle(4)
# Out:
# Total time: 01:51 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.259443</th>
#     <th>0.206021</th>
#     <th>0.074491</th>
#     <th>0.925509</th>
#     <th>0.924214</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.187036</th>
#     <th>0.163220</th>
#     <th>0.058866</th>
#     <th>0.941134</th>
#     <th>0.939866</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.176926</th>
#     <th>0.143175</th>
#     <th>0.051054</th>
#     <th>0.948946</th>
#     <th>0.948126</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.133450</th>
#     <th>0.135708</th>
#     <th>0.049237</th>
#     <th>0.950763</th>
#     <th>0.949355</th>
#   </tr>
# </table>
# Total time: 02:39 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.246255</th>
#     <th>0.188738</th>
#     <th>0.069404</th>
#     <th>0.930596</th>
#     <th>0.929364</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.172432</th>
#     <th>0.143756</th>
#     <th>0.050690</th>
#     <th>0.949310</th>
#     <th>0.948074</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.153237</th>
#     <th>0.136594</th>
#     <th>0.050690</th>
#     <th>0.949310</th>
#     <th>0.948016</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.141645</th>
#     <th>0.138862</th>
#     <th>0.051235</th>
#     <th>0.948765</th>
#     <th>0.946893</th>
#   </tr>
# </table>
# Total time: 05:01 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.214714</th>
#     <th>0.164862</th>
#     <th>0.058140</th>
#     <th>0.941860</th>
#     <th>0.940454</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.165523</th>
#     <th>0.138334</th>
#     <th>0.050327</th>
#     <th>0.949673</th>
#     <th>0.948484</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.135429</th>
#     <th>0.127762</th>
#     <th>0.045422</th>
#     <th>0.954578</th>
#     <th>0.953428</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.129969</th>
#     <th>0.124768</th>
#     <th>0.046693</th>
#     <th>0.953307</th>
#     <th>0.951864</th>
#   </tr>
# </table>
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /home/changebio/.torch/models/resnet101-5d3b4d8f.pth
# 100%|██████████| 178728960/178728960 [02:39<00:00, 1123626.88it/s]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/4 00:00<00:00]
#     </div>
#
# <table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#     <th>fbeta_binary</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='258', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-d840e7e4b878> in <module>
#       1 for m in model_meta.keys():
#       2     learn = create_cnn(data,m,metrics = [error_rate,accuracy, Fbeta_binary(beta2=1,clas = 1)])
# ----> 3     res=learn.fit_one_cycle(4)
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, wd, callbacks, **kwargs)
#      20     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor,
#      21                                         pct_start=pct_start, **kwargs))
# ---> 22     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      23
#      24 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, **kwargs:Any):
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     170         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#     171         fit(epochs, self.model, self.loss_func, opt=self.opt, data=self.data, metrics=self.metrics,
# --> 172             callbacks=self.callbacks+callbacks)
#     173
#     174     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, model, loss_func, opt, data, callbacks, metrics)
#      92     except Exception as e:
#      93         exception = e
# ---> 94         raise e
#      95     finally: cb_handler.on_train_end(exception)
#      96
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, model, loss_func, opt, data, callbacks, metrics)
#      82             for xb,yb in progress_bar(data.train_dl, parent=pbar):
#      83                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# ---> 84                 loss = loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      85                 if cb_handler.on_batch_end(loss): break
#      86
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      16     if not is_listy(xb): xb = [xb]
#      17     if not is_listy(yb): yb = [yb]
# ---> 18     out = model(*xb)
#      19     out = cb_handler.on_loss_begin(out)
#      20
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torchvision/models/resnet.py in forward(self, x)
#      82         out = self.relu(out)
#      83
# ---> 84         out = self.conv3(out)
#      85         out = self.bn3(out)
#      86
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     318     def forward(self, input):
#     319         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 320                         self.padding, self.dilation, self.groups)
#     321
#     322
#
# RuntimeError: CUDA out of memory. Tried to allocate 49.00 MiB (GPU 0; 10.91 GiB total capacity; 5.49 GiB already allocated; 32.81 MiB free; 153.73 MiB cached)

# %%
for i in model_type

# %%
learn.save('stage-1')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
losses,idxs = interp.top_losses()
len(data.valid_ds),len(losses),len(idxs)
# Out:
# (5512, 5504, 5504)

# %%
interp.plot_confusion_matrix()

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:51 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.141186</th>
#     <th>0.116783</th>
#     <th>0.039426</th>
#   </tr>
# </table>

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(2,max_lr=slice(1e-6,1e-4))
# Out:
# Total time: 01:43 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.118870</th>
#     <th>0.104693</th>
#     <th>0.037427</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.108816</th>
#     <th>0.105676</th>
#     <th>0.039426</th>
#   </tr>
# </table>

# %%
interp.plot_top_losses(9,figsize=(15,11))

# %%
from torch.utils.data.dataset import Dataset
from torchvision import transforms

class MyCustomDataset(Dataset):
    def __init__(self, ..., transforms=None):
        # stuff
        ...
        self.transforms = transforms
        
    def __getitem__(self, index):
        # stuff
        ...
        data = # Some data read from a file or image
        if self.transforms is not None:
            data = self.transforms(data)
        # If the transform variable is not empty
        # then it applies the operations in the transforms with the order that it is created.
        return (img, label)

    def __len__(self):
        return count # of how many data(images?) you have
    
transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.ToTensor(),
])
dataset = ImdbWikiDataset(transform=transform)
dataloader = DataLoader(dataset, batch_size=8, shuffle=True, num_workers=1)

# %%
data.valid_ds
# Out:
# LabelList
# y: CategoryList (5512 items)
# [Category 0, Category 1, Category 1, Category 0, Category 1]...
# Path: ../vision/MalariaCellImages_FlyAI/data/local/test
# x: ImageItemList (5512 items)
# [Image (3, 103, 145), Image (3, 151, 136), Image (3, 127, 118), Image (3, 148, 127), Image (3, 118, 103)]...
# Path: ../vision/MalariaCellImages_FlyAI/data/local/test

# %%
# ?DataLoader

# %%
data.valid_ds
# Out:
# LabelList
# y: CategoryList (3306 items)
# [Category 0, Category 0, Category 0, Category 1, Category 0]...
# Path: ../vision/MalariaCellImages_FlyAI/data/local/train
# x: ImageItemList (3306 items)
# [Image (3, 154, 124), Image (3, 124, 109), Image (3, 127, 112), Image (3, 148, 148), Image (3, 109, 106)]...
# Path: ../vision/MalariaCellImages_FlyAI/data/local/train

# %%
# ?ImageDataBunch.from_df
