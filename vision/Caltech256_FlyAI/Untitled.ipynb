# %%
import torch
import torch.nn as nn
import torchvision
from flyai.dataset import Dataset
from torch.autograd import Variable
from torch.optim import Adam
from model import Model
from path import MODEL_PATH

from dataset import Caltech256
from utils import Bunch
cuda_avail = torch.cuda.is_available()
# Out:
# Monkey-patching not on the main thread; threading.main_thread().join() will hang from a greenlet
# dev.zip total size:  4 MB
# [###########                                       ] 22%
# [##################                                ] 36%
# [#########################                         ] 50%
# [################################                  ] 64%
# [#######################################           ] 78%
# [##############################################    ] 92%
# [##################################################] 100%
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-10ca9c99f79d> in <module>
#       2 import torch.nn as nn
#       3 import torchvision
# ----> 4 from flyai.dataset import Dataset
#       5 from torch.autograd import Variable
#       6 from torch.optim import Adam
#
# ...

# %%
from path import DATA_PATH

# %%
from pathlib import PosixPath

# %%
import sys

# %%
p/"da
# Out:
# PosixPath('data')

# %%
p = PosixPath(sys.path[0])

# %%
# !wget -c https://dataset.flyai.com/dataset/ChestXray/
# Out:
# --2019-06-07 10:41:06--  https://dataset.flyai.com/dataset/ChestXray/
# Resolving dataset.flyai.com (dataset.flyai.com)... 219.147.82.232, 219.147.82.231, 219.147.82.230, ...
# Connecting to dataset.flyai.com (dataset.flyai.com)|219.147.82.232|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2019-06-07 10:41:06 ERROR 404: Not Found.

# %%
# Out:
# PosixPath('data/input')

# %%
nn.functional.nll_loss
# Out:
# <function torch.nn.functional.nll_loss(input, target, weight=None, size_average=None, ignore_index=-100, reduce=None, reduction='mean')>

# %%
def eval(model, x_test, y_test):
    cnn.eval()
    batch_eval = model.batch_iter(x_test, y_test)
    total_acc = 0.0
    data_len = len(x_test)
    for x_batch, y_batch in batch_eval:
        batch_len = len(x_batch)
        outputs = cnn(x_batch)
        _, prediction = torch.max(outputs.data, 1)
        correct = (prediction == y_batch).sum().item()
        acc = correct / batch_len
        total_acc += acc * batch_len
    return total_acc / data_len

outputs = cnn(x_train)
_, prediction = torch.max(outputs.data, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2b5a03f9b4fc> in <module>
#      13     return total_acc / data_len
#      14
# ---> 15 outputs = cnn(x_train)
#      16 _, prediction = torch.max(outputs.data, 1)
#
# NameError: name 'cnn' is not defined

# %%
from flyai.processor.download import check_download
from flyai.source.base import Base, DATA_PATH
from flyai.utils import read_data
from flyai.utils.yaml_helper import Yaml

# %%
caltech_dataset.__getitem__(1)[1]
# Out:
# 144

# %%
data = Dataset()
model = Model(data)

# %%
data.db.source.data.label
# Out:
# 0      96
# 1     144
# 2      56
# 3     191
# 4     153
# 5      72
# 6      69
# 7     255
# 8     233
# 9     229
# 10    125
# 11    176
# 12    217
# 13    104
# 14    105
# 15    163
# 16    239
# 17     38
# 18      4
# 19     50
# 20     95
# 21    234
# 22     32
# 23    174
# 24    144
# 25    131
# 26     91
# 27    211
# 28     13
# 29    213
#      ...
# 70    235
# 71    231
# 72    216
# 73    123
# 74    132
# 75     10
# 76    208
# 77    183
# 78    155
# 79    184
# 80    149
# 81    212
# 82     95
# 83     97
# 84     17
# 85    127
# 86    115
# 87     84
# 88     79
# 89    116
# 90     42
# 91    241
# 92     47
# 93      7
# 94     89
# 95    114
# 96    127
# 97    222
# 98    104
# 99    217
# Name: label, Length: 100, dtype: int64

# %%
def make_weights_for_balanced_classes(labels, nclasses):                        
    count = [0.1] * nclasses                                                      
    for item in labels:                                                         
        count[item] += 1                                                     
    weight_per_class = [0.1] * nclasses                                      
    N = float(sum(count))                                                   
    for i in range(nclasses):                                                   
        weight_per_class[i] = N/float(count[i])                                 
    weight = [0] * len(labels)                                              
    for idx, val in enumerate(labels):                                          
        weight[idx] = weight_per_class[val]                                  
    return weight

# %%
make_weights_for_balanced_classes(data.db.source.data.label,256)
# Out:
# [114.1818181818176,
#  40.51612903225786,
#  114.1818181818176,
#  59.809523809523505,
#  114.1818181818176,
#  114.1818181818176,
#  114.1818181818176,
#  114.1818181818176,
#  114.1818181818176,
#  59.809523809523505,
#  114.1818181818176,
#  114.1818181818176,
#  59.809523809523505,
#  59.809523809523505,
#  114.1818181818176,
#  114.1818181818176,
#  114.1818181818176,
#  114.1818181818176,
#  114.1818181818176,
#  114.1818181818176,
#  40.51612903225786,
#  114.1818181818176,
#  114.1818181818176,
#  114.1818181818176,
#  40.51612903225786,
#  114.1818181818176,
#  40.51612903225786,
#  114.1818181818176,
#  59.809523809523505,
#  114.1818181818176,
#  40.51612903225786,
#  114.1818181818176,
#  59.809523809523505,
#  59.809523809523505,
#  114.1818181818176,
#  114.1818181818176,
#  40.51612903225786,
#  114.1818181818176,
#  59.809523809523505,
#  114.1818181818176,
#  40.51612903225786,
#  114.1818181818176,
#  114.1818181818176,
#  114.1818181818176,
#  114.1818181818176,
# ...

# %%
import numpy as np

# %%
np.array([88,129,124,122,121,156,90,174,120,173])-np.array([56,99,90,95,57,100,57,116,82,114])
# Out:
# array([32, 30, 34, 27, 64, 56, 33, 58, 38, 59])

# %%
[88,129,124,122,121,156,90,174,120,173]
# Out:
# [88, 129, 124, 122, 121, 156, 90, 174, 120, 173]

# %%
for item in data.db.source.data.label:
    print(item)
# Out:
# 96
# 144
# 56
# 191
# 153
# 72
# 69
# 255
# 233
# 229
# 125
# 176
# 217
# 104
# 105
# 163
# 239
# 38
# 4
# 50
# 95
# 234
# 32
# 174
# 144
# 131
# 91
# 211
# 13
# 213
# 231
# 169
# 10
# 229
# 54
# 44
# 123
# 221
# 18
# 240
# 95
# 143
# 58
# 86
# 27
# 249
# 34
# 107
# 28
# 13
# 91
# 89
# 18
# 121
# 191
# 123
# 144
# 165
# 139
# 162
# 122
# 49
# 81
# 231
# 180
# 148
# 243
# 91
# 70
# 81
# 235
# 231
# 216
# 123
# 132
# 10
# 208
# 183
# 155
# 184
# 149
# 212
# 95
# 97
# 17
# 127
# 115
# 84
# 79
# 116
# 42
# 241
# 47
# 7
# 89
# 114
# 127
# 222
# 104
# 217

# %%
make_weights_for_balanced_classes([0,1,2,2,3,3,3],4)
# Out:
# [7.0,
#  7.0,
#  3.5,
#  3.5,
#  2.3333333333333335,
#  2.3333333333333335,
#  2.3333333333333335]

# %%
model.predict_all(data.db.source.data)
# Out:
# /home/changebio/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/serialization.py:434: SourceChangeWarning: source code of class 'torchvision.models.densenet.DenseNet' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# test data 100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-fac5b3c2cd55> in <module>
# ----> 1 model.predict_all(data.db.source.data)
#
# /mnt/Hdd/Proj/github/flyai/Caltech256_FlyAI/model.py in predict_all(self, datas)
#      43         for data in datas:
#      44             #print(data) #
# ---> 45             x_data = self.data.predict_data(**data)
#      46             x_data = torch.from_numpy(x_data)
#      47             x_data = x_data.float()
# ...

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
train_transforms= transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    normalize,
])
caltech_dataset = Caltech256(root=DATA_PATH,df=data.db.source.data,transform=train_transforms)

# %%
train_loader = torch.utils.data.DataLoader(caltech_dataset,
    batch_size=10, shuffle=True)

# %%
x,y = next(iter(train_loader))

# %%
data

# %%
y = y.float()

# %%
y = y/100

# %%
y.type()
# Out:
# 'torch.FloatTensor'

# %%
nn.MSELoss()(out,y)
# Out:
# tensor(0.9396, grad_fn=<MseLossBackward>)

# %%
numpy.argmax(out.data.numpy())
# Out:
# 49

# %%
a=numpy.array([1,2,2,2])

# %%
a[-1]
# Out:
# 2

# %%
numpy.around([1.0,2.01,11.7],decimals=1)
# Out:
# array([ 1. ,  2. , 11.7])

# %%
import pandas as pd

# %%
a=pd.read_csv("../vision/HumanFaceKeyPointDetection_FlyAI/data/input/dev.csv")

# %%
one = a.iloc[0]

# %%
b=one[1:]

# %%
np.ar

# %%
numpy.array(list(b))
# Out:
# array([ 70,  71, 107,  71,  88,  91,  72, 115, 104, 111])

# %%
b.to_numpy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-f43153865211> in <module>
# ----> 1 b.to_numpy()
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'to_numpy'

# %%
b.values.float()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-2e23c43e0407> in <module>
# ----> 1 b.values.float()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'float'

# %%
nn.MSELoss

# %%
cnn = torchvision.models.resnet34(pretrained=True)
for param in cnn.parameters():
    param.requires_grad = False
num_features = cnn.fc.in_features
cnn.fc = nn.Linear(num_features, 1)

# %%
out=cnn(x)

# %%
numpy.int(out.data.numpy()*10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-0b2a3439cbc8> in <module>
# ----> 1 numpy.int(out.data.numpy()*10)
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
cnn = torchvision.models.resnet34(pretrained=True)
for param in cnn.parameters():
    param.requires_grad = False
num_features = cnn.fc.in_features
cnn.fc = nn.Sequential(nn.Linear(num_features, 1),nn.Sigmoid())

# %%
cnn
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
# ...

# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms

    
def train(args, model, device, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

def test(args, model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

args = {'batch_size': 10,
 'test_batch_size': 100,
 'epochs': 10,
 'lr': 0.01,
 'momentum': 0.5,
 'no_cuda': False,
 'seed': 1,
 'log_interval': 10,
 'save_model': False}


args = Bunch(args)
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
train_transforms= transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    normalize,
])
val_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    normalize,
])
train_dataset = Caltech256(root=DATA_PATH,df=data.db.source.data,transform=train_transforms)
val_dataset = Caltech256(root=DATA_PATH,df=data.db.source.test,transform=val_transforms)

cnn = torchvision.models.densenet121(pretrained=True)
for param in cnn.parameters():
    param.requires_grad = False
num_features = cnn.classifier.in_features
cnn.classifier = nn.Linear(num_features, 256)

use_cuda = not args.no_cuda and torch.cuda.is_available()

torch.manual_seed(args.seed)

device = torch.device("cuda" if use_cuda else "cpu")

kwargs = {'num_workers': 2, 'pin_memory': True} if use_cuda else {}

train_loader = torch.utils.data.DataLoader(train_dataset,
    batch_size=args.batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(val_dataset,
    batch_size=args.test_batch_size, shuffle=True, **kwargs)


#model = Net().to(device)
model = cnn.to(device)
optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=args.momentum)

for epoch in range(1, args.epochs + 1):
    train(args, model, device, train_loader, optimizer, epoch)
    test(args, model, device, test_loader)

if (args.save_model):
    torch.save(model.state_dict(),"mnist_cnn.pt")

#if __name__ == '__main__':
#    main()
# Out:
# Train Epoch: 1 [0/100 (0%)]	Loss: 0.255130
#
# Test set: Average loss: -1.4771, Accuracy: 9/100 (9%)
#
# Train Epoch: 2 [0/100 (0%)]	Loss: -1.241166
#
# Test set: Average loss: -3.0886, Accuracy: 14/100 (14%)
#
# Train Epoch: 3 [0/100 (0%)]	Loss: -3.031448
#
# Test set: Average loss: -4.7495, Accuracy: 18/100 (18%)
#
# Train Epoch: 4 [0/100 (0%)]	Loss: -3.339847
#
# Test set: Average loss: -6.3826, Accuracy: 15/100 (15%)
#
# Train Epoch: 5 [0/100 (0%)]	Loss: -7.767787
#
# Test set: Average loss: -8.1429, Accuracy: 15/100 (15%)
#
# Train Epoch: 6 [0/100 (0%)]	Loss: -5.496439
#
# Test set: Average loss: -9.5678, Accuracy: 16/100 (16%)
#
# Train Epoch: 7 [0/100 (0%)]	Loss: -6.891263
#
# Test set: Average loss: -11.2945, Accuracy: 17/100 (17%)
#
# Train Epoch: 8 [0/100 (0%)]	Loss: -9.671156
#
# Test set: Average loss: -12.9527, Accuracy: 17/100 (17%)
#
# Train Epoch: 9 [0/100 (0%)]	Loss: -9.648602
#
# Test set: Average loss: -14.5734, Accuracy: 17/100 (17%)
#
# ...

# %%
nn.CrossEntropyLoss

# %%
 train_path = check_download(config['train_url'], DATA_PATH, is_print=line)
        self.data = read_data.read(train_path)
        test_path = check_download(config['test_url'], DATA_PATH, is_print=line)
        self.test = read_data.read(test_path)

# %%
def score(p,y):
    _,yp = torch.max(p.data,1)
    return (yp == y).sum().item()/len(y)

# %%
def train_net(data,net,ep=10,bz=64,gpu=True,loss_fn = nn.CrossEntropyLoss(),optimizer = Adam(cnn.parameters(), lr=0.001, betas=(0.9, 0.999))):
    net.train()
    ave_loss=0
    ave_score=0
    for _ in range(ep):
        #read data batch by batch
        x_train, y_train, _ , _ = data.next_batch(bz) 
        x_train = torch.from_numpy(x_train)
        y_train = torch.from_numpy(y_train)
        x_train = x_train.float()

        if gpu:
            x_train = Variable(x_train.cuda())
            y_train = Variable(y_train.cuda())
        
        y_outs = net(x_train)
        optimizer.zero_grad()
        loss = loss_fn(net(x_train), y_train)
        loss.backward()
        optimizer.step()
        ave_loss += loss.data.item()
        ave_score +=score(y_outs,y_train)
        print(ave_loss/ep,ave_score/ep)
    return net

# %%
def test_net(data,net,bz=64,gpu=True,loss_fn = nn.CrossEntropyLoss()):
    net.eval()
    ave_loss=0
    ave_score=0
    #read data batch by batch
    _,_, x_test, y_test = data.next_batch(bz) 
    x_test = torch.from_numpy(x_test)
    y_test = torch.from_numpy(y_test)
    x_test = x_test.float()

    if gpu:
        x_test = Variable(x_test.cuda())
        y_test = Variable(y_test.cuda())

    y_outs = net(x_test)
    loss = loss_fn(y_outs, y_test)
    ave_loss += loss.data.item()
    ave_score +=score(y_outs,y_test)
    print(ave_loss/ep,ave_score/ep)
    return net, loss.data.item(),

# %%
net = train_net(data,cnn,ep=10)
# Out:
# 0.46059422492980956 0.0125
# 0.920838451385498 0.021875
# 1.3807608127593993 0.0296875
# 1.8403891563415526 0.0359375
# 2.2997533321380614 0.0421875
# 2.758884620666504 0.0484375
# 3.2178132057189943 0.0546875
# 3.676563930511475 0.059375
# 4.135154771804809 0.0640625
# 4.593596315383911 0.06875

# %%
net(x_test)
# Out:
# tensor([[0.0036, 0.0093, 0.0116,  ..., 0.0078, 0.0075, 0.6458],
#         [0.0319, 0.0343, 0.0309,  ..., 0.0247, 0.0300, 0.5325],
#         [0.0104, 0.0093, 0.0159,  ..., 0.0082, 0.0091, 0.7882],
#         ...,
#         [0.0129, 0.0181, 0.0278,  ..., 0.0062, 0.0112, 0.5283],
#         [0.0380, 0.0279, 0.0114,  ..., 0.0059, 0.0056, 0.6189],
#         [0.0077, 0.0065, 0.0136,  ..., 0.0054, 0.0034, 0.8602]],
#        device='cuda:0', grad_fn=<SigmoidBackward>)

# %%
import numpy as np

# %%
loss.data[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-debf4cef1c62> in <module>
# ----> 1 loss.data[0]
#
# IndexError: invalid index of a 0-dim tensor. Use tensor.item() to convert a 0-dim tensor to a Python number

# %%
## 定义DenseNet实例,加载与训练模型，并更改最后一层
cnn = torchvision.models.resnet34(pretrained=True)

# %%
cnn1 = torchvision.models.densenet121(pretrained=True)
# Out:
# /home/changebio/anaconda3/envs/fastv1/lib/python3.6/site-packages/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)

# %%
cnn.fc.out_features
# Out:
# 1000

# %%
cnn = torchvision.models.resnet34(pretrained=True)
for param in cnn.parameters():
    param.requires_grad = False
num_features = cnn.fc.in_features
cnn.fc = nn.Sequential(nn.Linear(num_features, 256),nn.Sigmoid())

if cuda_avail:
    cnn.cuda()

optimizer = Adam(cnn.parameters(), lr=0.001, betas=(0.9, 0.999))  # 选用AdamOptimizer
loss_fn = nn.CrossEntropyLoss()  # 定义损失函数

# 训练并评估模型

data = Dataset()
model = Model(data)

# %%
data = Dataset()
model = Model(data)

# %%
def eval(model, x_test, y_test):
    cnn.eval()
    batch_eval = model.batch_iter(x_test, y_test)
    total_acc = 0.0
    data_len = len(x_test)
    for x_batch, y_batch in batch_eval:
        batch_len = len(x_batch)
        outputs = cnn(x_batch)
        _, prediction = torch.max(outputs.data, 1)
        correct = (prediction == y_batch).sum().item()
        acc = correct / batch_len
        total_acc += acc * batch_len
    return total_acc / data_len

# %%
x_test.shape
# Out:
# torch.Size([32, 3, 224, 224])

# %%
yaml = Yaml()

# %%
yaml.data
# Out:
# {'name': 'Caltech256 classification',
#  'author': 'ChangeBio',
#  'description': 'Caltech256 classification',
#  'topic': 'Caltech256 classification',
#  'algorithm': 'DenseNet',
#  'language': 'python3',
#  'virtualenv': 'flyai_env/bin/',
#  'framework': 'PyTorch',
#  'data': {'id': 'Caltech256',
#   'name': 'Caltech256 classification',
#   'category': 'image'},
#  'model': {'processor': 'Processor',
#   'input_x': 'input_x',
#   'input_y': 'input_y',
#   'output_y': 'output_y',
#   'input': {'columns': [{'name': 'image_path', 'type': 'url'}],
#    'to_type': 'float',
#    'to_shape': [-1, '224*224']},
#   'output': {'columns': [{'name': 'label', 'type': 'int'}],
#    'to_type': 'float',
#    'to_shape': [-1, 256]},
#   'transfer_learning': 'https://download.pytorch.org/models/densenet121-241335ed.pth'},
#  'evaluate': {'score': 'torch_accuracy'},
#  'servers': [{'id': 'flyai', 'url': 'https://flyai.com'}]}

# %%
import os
import sys

# %%
try:
    f = open(os.path.join(sys.path[0], 'train.json'))
    line = f.readline().strip()
except IOError:
    line = ""
print(line)

# %%
import sys
from time import time

import json
import os
import platform
import random
import requests

from flyai.source.base import Base, DATA_PATH
from flyai.utils.yaml_helper import Yaml

# %%
postdata = {'id': yaml.get_data_id(),
            'env': line,
            'time': time(),
            'sign': random.random(),
            'goos': platform.platform()}
postdata
# Out:
# {'id': 'Caltech256',
#  'env': '',
#  'time': 1556461215.2949138,
#  'sign': 0.8616169196182673,
#  'goos': 'Linux-4.15.0-48-generic-x86_64-with-debian-buster-sid'}

# %%
servers = yaml.get_servers()
r = requests.post(servers[0]['url'] + "/dataset", data=postdata)
source = json.loads(r.text)

# %%
source
# Out:
# {'status': 1,
#  'message': 'success',
#  'url': 'https://dataset.flyai.com/dataset/Caltech256/test.zip',
#  'yaml': {'id': 'Caltech256',
#   'type': 'csv',
#   'config': {'train_url': 'https://dataset.flyai.com/dataset/Caltech256/dev.zip',
#    'test_url': 'https://dataset.flyai.com/dataset/Caltech256/dev.zip'}},
#  'venv': 'https://dataset.flyai.com/flyai_env3.6.4_linux.zip'}

# %%
config = source['yaml']['config']

# %%
cnn.train()
x_train, y_train, x_test, y_test = data.next_batch(32)  # 读取数据

x_train = torch.from_numpy(x_train)
y_train = torch.from_numpy(y_train)
x_train = x_train.float()

x_test = torch.from_numpy(x_test)
y_test = torch.from_numpy(y_test)
x_test = x_test.float()

if cuda_avail:
    x_train = Variable(x_train.cuda())
    y_train = Variable(y_train.cuda())
    x_test = Variable(x_test.cuda())
    y_test = Variable(y_test.cuda())

outputs = cnn(x_train)
_, prediction = torch.max(outputs.data, 1)

optimizer.zero_grad()

loss = loss_fn(outputs, y_train)
loss.backward()
optimizer.step()

# %%
loss
# Out:
# tensor(5.5358, device='cuda:0', grad_fn=<NllLossBackward>)

# %%
# -*- coding: utf-8 -*
# author Huangyin

from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import transforms
from torch.optim import Adam
from torch.autograd import Variable

from flyai.dataset import Dataset
from flyai.source.base import DATA_PATH

from model import Model
from path import MODEL_PATH
from processor import Caltech256
from utils import Bunch
    
def train(args, model, device, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

def test(args, model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

    
def pretrained_net(net,class_num):
    if net=='densenet121':
        cnn = torchvision.models.densenet121(pretrained=True)
        for param in cnn.parameters():
            param.requires_grad = False
        num_features = cnn.classifier.in_features
        cnn.classifier = nn.Linear(num_features, class_num)
    elif net=='resnet34':
        cnn = torchvision.models.resnet34(pretrained=True)
        for param in cnn.parameters():
            param.requires_grad = False
        num_features = cnn.fc.in_features
        cnn.fc = nn.Sequential(nn.Linear(num_features, class_num),nn.Sigmoid())
    return cnn

def score(p,y):
    _,yp = torch.max(p.data,1)
    return (yp == y).sum().item()/len(y)


    
def eval(model, x_test, y_test):
    net.eval()
    batch_eval = model.batch_iter(x_test, y_test)
    total_acc = 0.0
    data_len = len(x_test)
    for x_batch, y_batch in batch_eval:
        batch_len = len(x_batch)
        outputs = net(x_batch)
        _, prediction = torch.max(outputs.data, 1)
        correct = (prediction == y_batch).sum().item()
        acc = correct / batch_len
        total_acc += acc * batch_len
    return total_acc / data_len
       



parser = argparse.ArgumentParser()
parser.add_argument("-e", "--EPOCHS", default=10, type=int, help="train epochs")
parser.add_argument("-b", "--BATCH", default=32, type=int, help="batch size")
args = parser.parse_args()


#settings
settings = {
'net':'densenet121',
'nc':256,    
'lr': 0.01,
'seed': 1,
'log_interval': 10,
'save_model': True}
#print("1.settings",settings)
settings = Bunch(settings)
use_cuda = torch.cuda.is_available()
torch.manual_seed(settings.seed)
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 2, 'pin_memory': True} if use_cuda else {}



#load data
data = Dataset()
model = Model(data)
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
train_transforms= transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    normalize,
])
val_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    normalize,
])
train_dataset = Caltech256(root=DATA_PATH,df=data.db.source.data,transform=train_transforms)
val_dataset = Caltech256(root=DATA_PATH,df=data.db.source.test,transform=val_transforms)
train_loader = torch.utils.data.DataLoader(train_dataset,
    batch_size=args.BATCH, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(val_dataset,
    batch_size=args.BATCH, shuffle=True, **kwargs)
n_train = len(train_dataset)
batch_train = n_train/args.BATCH
n_test = len(val_dataset)
batch_test = n_test/args.BATCH
print("4. load data. train_dataset %d,batch %d, val_dataset %d, batch %d." % (n_train,batch_train,n_test,batch_test))


print("2.load net structure: %s, number of class: %d" % (settings.net,settings.nc))
net = pretrained_net(settings.net,settings.nc)
gpu = torch.cuda.is_available()
if gpu:
    net.cuda()

print("3.optimize and loss. learning rate %g" % settings.lr)
optimizer = Adam(net.parameters(), lr=settings.lr, betas=(0.9, 0.999))  
loss_fn = nn.CrossEntropyLoss()


print("5.***************train and test*********************")
best_accuracy = 0
train_iter = iter(train_loader)
batch_idx = 0    
for i in range(args.EPOCHS):
    net.train()
    x_train, y_train, x_test, y_test = data.next_batch(32)
    #x_train, y_train, x_test, y_test = data.next_batch(args.BATCH) 
        #x_train = torch.from_numpy(x_train)
        #y_train = torch.from_numpy(y_train)
        #x_train = x_train.float()
    try:
        batch_idx +=1
        x_train, y_train = next(train_iter)
        print(batch_idx,"data len",len(x_train),len(y_train))
    except:
        batch_idx = 0
        train_iter = iter(train_loader)
        x_train, y_train = next(train_iter)
        print(len(x_train),len(y_train),"data len")

    if gpu:
        x_train = Variable(x_train.cuda())
        y_train = Variable(y_train.cuda())


    outputs = net(x_train)
    optimizer.zero_grad()
    loss = loss_fn(outputs, y_train)
    loss.backward()
    optimizer.step()
    if i % 5 == 0:
        print("batch: %d,train loss: %g, train score: %g" % (batch_idx,loss.data.item(), score(outputs,y_train)))

if settings.save_model:       
    model.save_model(net, MODEL_PATH, overwrite=True)

# %%
best_accuracy = 0
for i in range(100):
    cnn.train()
    x_train, y_train, x_test, y_test = data.next_batch(32)  # 读取数据

    x_train = torch.from_numpy(x_train)
    y_train = torch.from_numpy(y_train)
    x_train = x_train.float()

    x_test = torch.from_numpy(x_test)
    y_test = torch.from_numpy(y_test)
    x_test = x_test.float()

    if cuda_avail:
        x_train = Variable(x_train.cuda())
        y_train = Variable(y_train.cuda())
        x_test = Variable(x_test.cuda())
        y_test = Variable(y_test.cuda())

    outputs = cnn(x_train)
    _, prediction = torch.max(outputs.data, 1)

    optimizer.zero_grad()

    loss = loss_fn(outputs, y_train)
    loss.backward()
    optimizer.step()
    # 若测试准确率高于当前最高准确率，则保存模型
    train_accuracy = eval(model, x_test, y_test)
    if train_accuracy > best_accuracy:
        best_accuracy = train_accuracy
        model.save_model(cnn, MODEL_PATH, overwrite=True)
        print("step %d, best accuracy %g" % (i, best_accuracy))

    print(str(i) + "/" + str(100))
# Out:
# step 0, best accuracy 0.03125
# 0/100
# 1/100
# 2/100
# 3/100
# step 4, best accuracy 0.0625
# 4/100
# 5/100
# 6/100
# 7/100
# 8/100
# 9/100
# 10/100
# 11/100
# 12/100
# 13/100
# 14/100
# 15/100
# 16/100
# 17/100
# step 18, best accuracy 0.09375
# 18/100
# 19/100
# 20/100
# 21/100
# 22/100
# 23/100
# 24/100
# 25/100
# 26/100
# 27/100
# 28/100
# 29/100
# 30/100
# 31/100
# 32/100
# 33/100
# 34/100
# 35/100
# 36/100
# 37/100
# 38/100
# 39/100
# 40/100
# 41/100
# 42/100
# 43/100
# 44/100
# 45/100
# 46/100
# 47/100
# 48/100
# 49/100
# 50/100
# 51/100
# 52/100
# 53/100
# 54/100
# 55/100
# 56/100
# 57/100
# 58/100
# 59/100
# 60/100
# 61/100
# 62/100
# 63/100
# 64/100
# 65/100
# 66/100
# 67/100
# 68/100
# 69/100
# 70/100
# 71/100
# 72/100
# 73/100
# 74/100
# 75/100
# 76/100
# 77/100
# 78/100
# 79/100
# 80/100
# 81/100
# 82/100
# 83/100
# 84/100
# 85/100
# 86/100
# 87/100
# 88/100
# 89/100
# 90/100
# 91/100
# 92/100
# 93/100
# 94/100
# 95/100
# 96/100
# 97/100
# 98/100
# 99/100

# %%
data.get_all_data()
# Out:
# ([{'image_path': 'image/097.harmonica/097_0010.jpg'},
#   {'image_path': 'image/145.motorbikes-101/145_0455.jpg'},
#   {'image_path': 'image/057.dolphin-101/057_0072.jpg'},
#   {'image_path': 'image/192.snowmobile/192_0093.jpg'},
#   {'image_path': 'image/154.palm-tree/154_0101.jpg'},
#   {'image_path': 'image/073.fireworks/073_0092.jpg'},
#   {'image_path': 'image/070.fire-extinguisher/070_0023.jpg'},
#   {'image_path': 'image/256.toad/256_0051.jpg'},
#   {'image_path': 'image/234.tweezer/234_0020.jpg'},
#   {'image_path': 'image/230.trilobite-101/230_0005.jpg'},
#   {'image_path': 'image/126.ladder/126_0201.jpg'},
#   {'image_path': 'image/177.saturn/177_0059.jpg'},
#   {'image_path': 'image/218.tennis-racket/218_0068.jpg'},
#   {'image_path': 'image/105.horse/105_0036.jpg'},
#   {'image_path': 'image/106.horseshoe-crab/106_0006.jpg'},
#   {'image_path': 'image/164.porcupine/164_0096.jpg'},
#   {'image_path': 'image/240.watch-101/240_0038.jpg'},
# ...

# %%
[len(i) for i in data.get_all_data()]
# Out:
# [100, 100, 100, 100]

# %%
train_loader[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-e2ab3ea573f3> in <module>
# ----> 1 train_loader[0]
#
# TypeError: 'DataLoader' object does not support indexing

# %%
from processor import Processor

# %%
from __future__ import print_function
from torch.utils.data.dataset import Dataset
from torchvision import transforms

import numpy
from PIL import Image
from flyai.processor.base import Base
from flyai.processor.download import check_download

from path import DATA_PATH

# %%
path = check_download("image/008.bathtub/008_0050.jpg", DATA_PATH)
image = Image.open(path)
image = image.convert('RGB')
image = image.resize((224, 224))
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
pred_transforms = transforms.Compose([
    transforms.ToTensor(),
    normalize,
])
pred_transforms(image)
# Out:
# tensor([[[ 1.6838,  1.7352,  1.5639,  ...,  1.6838,  1.7009,  1.1872],
#          [ 1.6667,  1.6838,  1.4954,  ...,  1.5468,  1.3413,  0.6563],
#          [ 1.3927,  1.3584,  1.1015,  ...,  1.0673,  0.8961,  0.3138],
#          ...,
#          [ 1.2557,  1.0331,  0.8104,  ...,  0.8447,  0.5364,  0.1254],
#          [ 0.8104,  0.3138,  0.0569,  ..., -0.0116, -0.0972, -0.1314],
#          [ 0.1768, -0.3027, -0.2171,  ..., -0.2513, -0.1657, -0.1657]],
#
#         [[ 1.6232,  1.6583,  1.4307,  ...,  1.4482,  1.2556,  0.6954],
#          [ 1.4482,  1.4482,  1.1856,  ...,  1.1681,  0.7479, -0.0399],
#          [ 0.9405,  0.8704,  0.5553,  ...,  0.4678,  0.0476, -0.6176],
#          ...,
#          [ 0.5553,  0.3102, -0.0049,  ..., -0.0399, -0.4951, -0.9853],
#          [-0.0224, -0.5826, -0.8978,  ..., -1.0203, -1.1779, -1.2654],
#          [-0.7227, -1.2479, -1.2479,  ..., -1.3354, -1.3004, -1.3179]],
#
#         [[ 1.2282,  1.1934,  0.8797,  ...,  0.8971,  0.2871, -0.4450],
# ...

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FBF123C00F0>

# %%
a= Processor()

# %%
??a.input_x

# %%
b=a.input_x("image/008.bathtub/008_0050.jpg")
# Out:
# image process

# %%
b
# Out:
# tensor([[[ 1.6838,  1.7352,  1.5639,  ...,  1.6838,  1.7009,  1.1872],
#          [ 1.6667,  1.6838,  1.4954,  ...,  1.5468,  1.3413,  0.6563],
#          [ 1.3927,  1.3584,  1.1015,  ...,  1.0673,  0.8961,  0.3138],
#          ...,
#          [ 1.2557,  1.0331,  0.8104,  ...,  0.8447,  0.5364,  0.1254],
#          [ 0.8104,  0.3138,  0.0569,  ..., -0.0116, -0.0972, -0.1314],
#          [ 0.1768, -0.3027, -0.2171,  ..., -0.2513, -0.1657, -0.1657]],
#
#         [[ 1.6232,  1.6583,  1.4307,  ...,  1.4482,  1.2556,  0.6954],
#          [ 1.4482,  1.4482,  1.1856,  ...,  1.1681,  0.7479, -0.0399],
#          [ 0.9405,  0.8704,  0.5553,  ...,  0.4678,  0.0476, -0.6176],
#          ...,
#          [ 0.5553,  0.3102, -0.0049,  ..., -0.0399, -0.4951, -0.9853],
#          [-0.0224, -0.5826, -0.8978,  ..., -1.0203, -1.1779, -1.2654],
#          [-0.7227, -1.2479, -1.2479,  ..., -1.3354, -1.3004, -1.3179]],
#
#         [[ 1.2282,  1.1934,  0.8797,  ...,  0.8971,  0.2871, -0.4450],
# ...

# %%
train_dataset.__getitem__(0)[0].cuda()
# Out:
# tensor([[[ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#          [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#          [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#          ...,
#          [-0.7650, -0.6452, -1.0733,  ..., -1.4158, -1.2103, -0.6281],
#          [-0.7479, -0.3369, -0.2513,  ...,  0.1254,  0.1768,  0.5364],
#          [-0.8678, -0.6109,  0.0227,  ...,  0.8961,  0.7933,  0.6392]],
#
#         [[ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#          [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#          [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#          ...,
#          [-0.7577, -0.5651, -1.0903,  ..., -1.6856, -1.5630, -1.0903],
#          [-0.9678, -0.4251, -0.3901,  ..., -0.4951, -0.6352, -0.4076],
#          [-1.0903, -0.7402, -0.1625,  ...,  0.0651, -0.1450, -0.4426]],
#
#         [[ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
# ...

# %%
nn.

# %%
if __name__ == '__main__':
    
    parser = argparse.ArgumentParser()
    parser.add_argument("-e", "--EPOCHS", default=10, type=int, help="train epochs")
    parser.add_argument("-b", "--BATCH", default=32, type=int, help="batch size")
    args = parser.parse_args()
    
    #settings
    settings = Bunch({
    'lr': 0.01,
    'seed': 1,
    'log_interval': 10,
    'save_model': True})
    use_cuda = torch.cuda.is_available()
    torch.manual_seed(settings.seed)
    device = torch.device("cuda" if use_cuda else "cpu")
    kwargs = {'num_workers': 2, 'pin_memory': True} if use_cuda else {}
    
    #load data
    data = Dataset()
    model = Model(data)
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
    train_transforms= transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize,
    ])
    val_transforms = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        normalize,
    ])
    train_dataset = Caltech256(root=DATA_PATH,df=data.db.source.data,transform=train_transforms)
    val_dataset = Caltech256(root=DATA_PATH,df=data.db.source.test,transform=val_transforms)
    train_loader = torch.utils.data.DataLoader(train_dataset,
        batch_size=args.BATCH, shuffle=True, **kwargs)
    test_loader = torch.utils.data.DataLoader(val_dataset,
        batch_size=args.BATCH, shuffle=True, **kwargs)
    
    #load net structure
    net = pretrained_net('densenet121',256)
    net = net.to(device)

    #optimize and loss
    optimizer = Adam(net.parameters(), lr=settings.lr, betas=(0.9, 0.999))  
    #loss_fn = nn.CrossEntropyLoss()  

    
    #training and testing
    best_accuracy = 0
  
    train_iter = iter(train_loader)
    test_iter = iter(test_loader)
    batch_idx = 0
    for epoch in range(args.EPOCHS):
        net.train()
        try:
            batch_idx +=1
            data, target = next(train_iter)
        except:
            batch_idx = 0
            train_iter = iter(train_loader)
            data, target = next(train_iter)
            print(len(data),len(target),"data len")
     
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = net(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % settings.log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
            
        net.eval()
        test_loss = 0
        correct = 0
        with torch.no_grad():
            try:
                batch_idx +=1
                data, target = next(test_iter)
            except:
                batch_idx = 0
                train_iter = iter(test_loader)
                data, target = next(train_iter)
                print("test data")
            data, target = data.to(device), target.to(device)
            output = net(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

        print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, correct, len(test_loader.dataset),
            100. * correct / len(test_loader.dataset)))

        #train_accuracy = eval(model, x_test, y_test)
        train_accuracy = correct
        if train_accuracy > best_accuracy:
            best_accuracy = train_accuracy
            #model.save_model(net, MODEL_PATH, overwrite=True)
            print("step %d, best accuracy %g" % (epoch, best_accuracy))

    #for epoch in range(1, args.EPOCHS + 1):
    #    train(settings, net, device, train_loader, optimizer, epoch)
    #    test(settings, net, device, test_loader)

    if settings.save_model:
        model.save_model(net, MODEL_PATH, overwrite=True)

# %%
data.predict_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-2b373c6c4d93> in <module>
# ----> 1 data.predict_data()
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/flyai/dataset.py in predict_data(self, **data)
#     150     def predict_data(self, **data):
#     151         processors = []
# --> 152         processor = self.get_method_dict(self.processor, self.model['output_x'], **data)
#     153         processor_len = 0
#     154         if not isinstance(processor, tuple):
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/flyai/dataset.py in get_method_dict(self, clz, method_name, **args)
#     185     def get_method_dict(self, clz, method_name, **args):
#     186         m = getattr(clz, method_name)
# --> 187         return m(**args)
#     188
#     189     def get_method_list(self, clz, method_name, *args):
#
# ...

# %%
data.predict_data(image_path="image/008.bathtub/008_0050.jpg")
# Out:
# array([[[[ 5.2348967 ,  5.4592385 ,  4.711433  , ...,  5.2348967 ,
#            5.3096776 ,  3.06626   ],
#          [ 5.160116  ,  5.2348967 ,  4.4123106 , ...,  4.636652  ,
#            3.7392852 ,  0.74806195],
#          [ 3.963627  ,  3.8140657 ,  2.6923568 , ...,  2.5427961 ,
#            1.7949902 , -0.7475496 ],
#          ...,
#          [ 3.3653824 ,  2.3932347 ,  1.4210871 , ...,  1.5706484 ,
#            0.22459784, -1.570136  ],
#          [ 1.4210871 , -0.7475496 , -1.8692588 , ..., -2.1683812 ,
#           -2.542284  , -2.6918452 ],
#          [-1.3457943 , -3.439651  , -3.065748  , ..., -3.2153094 ,
#           -2.8414066 , -2.8414066 ]],
#
#         [[ 5.210934  ,  5.367247  ,  4.3512154 , ...,  4.429372  ,
#            3.5696528 ,  1.0686529 ],
#          [ 4.429372  ,  4.429372  ,  3.257028  , ...,  3.1788716 ,
#            1.3031216 , -2.2139103 ],
#          [ 2.1628404 ,  1.8502153 ,  0.4434028 , ...,  0.05262145,
#           -1.8231292 , -4.793067  ],
# ...

# %%
from flyai.dataset import Dataset

from model import Model
from path import MODEL_PATH

data = Dataset()
model = Model(data)
p = model.predict(image_path="image/008.bathtub/008_0050.jpg")
print(p)
# Out:
# 174

# %%
[model.predict(image_path=i['image_path']) for i in data.get_all_data()[0]]
# Out:
# [174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174]

# %%
data.get_all_data()[0][0]
# Out:
# {'image_path': 'image/097.harmonica/097_0010.jpg'}

# %%
data.processor.input_x('image/097.harmonica/097_0010.jpg')
# Out:
# tensor([[[2.2489, 2.2489, 2.2489,  ..., 2.2318, 2.2318, 2.2318],
#          [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2318],
#          [2.2489, 2.2489, 2.2489,  ..., 2.2318, 2.2489, 2.2489],
#          ...,
#          [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#          [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#          [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#         [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4111, 2.4286],
#          [2.4286, 2.4286, 2.4286,  ..., 2.4111, 2.4111, 2.4286],
#          [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4111],
#          ...,
#          [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#          [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#          [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#         [[2.6400, 2.6400, 2.6400,  ..., 2.0997, 2.1346, 2.0125],
#          [2.6400, 2.6400, 2.6400,  ..., 2.0823, 1.9603, 2.3263],
# ...

# %%
model.predict(data=data.get_all_data()[0][0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-9a5bd077f8c8> in <module>
# ----> 1 model.predict(data=data.get_all_data()[0][0])
#
# /mnt/Hdd/Proj/github/flyai/Caltech256_FlyAI/model.py in predict(self, **data)
#      24         if cuda_avail:
#      25             cnn.cuda()
# ---> 26         x_data = self.data.predict_data(**data)
#      27         x_data = torch.from_numpy(x_data)
#      28         x_data = x_data.float()
#
# ~/anaconda3/envs/fastv1/lib/python3.6/site-packages/flyai/dataset.py in predict_data(self, **data)
#     150     def predict_data(self, **data):
#     151         processors = []
# --> 152         processor = self.get_method_dict(self.processor, self.model['output_x'], **data)
#     153         processor_len = 0
#     154         if not isinstance(processor, tuple):
#
# ...

# %%
model.predict_all(data.get_all_data()[0][0])
# Out:
# test data 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-fba3544a5d6a> in <module>
# ----> 1 model.predict_all(data.get_all_data()[0][0])
#
# /mnt/Hdd/Proj/github/flyai/Caltech256_FlyAI/model.py in predict_all(self, datas)
#      43         for data in datas:
#      44             #print(data) #
# ---> 45             x_data = self.data.predict_data(**data)
#      46             x_data = torch.from_numpy(x_data)
#      47             x_data = x_data.float()
#
# TypeError: predict_data() argument after ** must be a mapping, not str

# %%
a=np.concatenate((np.ones((32,25,2)),np.zeros((32,25,2))),axis=2)

# %%
a.ravel()
# Out:
# array([1., 1., 0., ..., 1., 0., 0.])

# %%
a.view(a.size(0),a.size(1)*a.size(2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-d455a9539c79> in <module>
# ----> 1 a.view(a.size(0),a.size(1)*a.size(2))
#
# TypeError: 'int' object is not callable

# %%
model.predict_all(data.get_all_data()[0])
# Out:
# /home/changebio/anaconda3/envs/fastv1/lib/python3.6/site-packages/torch/serialization.py:434: SourceChangeWarning: source code of class 'torchvision.models.densenet.DenseNet' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# test data 100
# [174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
#  174,
# ...

# %%
import numpy as np

# %%
[1,2]*np.array([1,2,3,4])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-fe9647ff3878> in <module>
# ----> 1 [1,2]*np.array([1,2,3,4])
#
# ValueError: operands could not be broadcast together with shapes (2,) (4,)

# %%
data.predict_data(data.get_all_data()[0][0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-e155e3cdd4a3> in <module>
# ----> 1 data.predict_data(data.get_all_data()[0][0])
#
# TypeError: predict_data() takes 1 positional argument but 2 were given

# %%
??model.predict_all

# %%
! chmod +x flyai

# %%
! ./flyai train -p=1 -b=32 -e=100
# Out:
# 代码提交中请等待 ...
# 离线训练提交成功！复制链接到浏览器，登录后即可查看实时训练日志。
# https://flyai.com/training_result/taind1b41b6d26a5ec054b54437f

# %%
1001 % 10
# Out:
# 1

# %%
# -*- coding: utf-8 -*
import argparse
import torch
import torch.nn as nn
import torchvision
from flyai.dataset import Dataset
from torch.autograd import Variable
from torch.optim import Adam

from model import Model
from path import MODEL_PATH

cuda_avail = torch.cuda.is_available()
# 数据获取辅助类
dataset = Dataset()

# 模型操作辅助类
model = Model(dataset)

# 超参
parser = argparse.ArgumentParser()
parser.add_argument("-e", "--EPOCHS", default=10, type=int, help="train epochs")
parser.add_argument("-b", "--BATCH", default=1, type=int, help="batch size")
args = parser.parse_args()


def eval(model, x_test, y_test):
    cnn.eval()
    batch_eval = model.batch_iter(x_test, y_test)
    total_acc = 0.0
    data_len = len(x_test)
    for x_batch, y_batch in batch_eval:
        batch_len = len(x_batch)
        outputs = cnn(x_batch)
        _, prediction = torch.max(outputs.data, 1)
        correct = (prediction == y_batch).sum().item()
        acc = correct / batch_len
        total_acc += acc * batch_len
    return total_acc / data_len


## 定义DenseNet实例,加载与训练模型，并更改最后一层
cnn = torchvision.models.densenet121(pretrained=True)
for param in cnn.parameters():
    param.requires_grad = False
num_features = cnn.classifier.in_features
cnn.classifier = nn.Linear(num_features, 256)

if cuda_avail:
    cnn.cuda()

optimizer = Adam(cnn.parameters(), lr=0.001, betas=(0.9, 0.999))  # 选用AdamOptimizer
loss_fn = nn.CrossEntropyLoss()  # 定义损失函数

# 训练并评估模型

data = Dataset()
model = Model(data)

best_accuracy = 0
for i in range(args.EPOCHS):
    cnn.train()
    x_train, y_train, x_test, y_test = data.next_batch(args.BATCH)  # 读取数据

    x_train = torch.from_numpy(x_train)
    y_train = torch.from_numpy(y_train)
    x_train = x_train.float()

    x_test = torch.from_numpy(x_test)
    y_test = torch.from_numpy(y_test)
    x_test = x_test.float()

    if cuda_avail:
        x_train = Variable(x_train.cuda())
        y_train = Variable(y_train.cuda())
        x_test = Variable(x_test.cuda())
        y_test = Variable(y_test.cuda())

    outputs = cnn(x_train)
    _, prediction = torch.max(outputs.data, 1)

    optimizer.zero_grad()

    loss = loss_fn(outputs, y_train)
    loss.backward()
    optimizer.step()
    # 若测试准确率高于当前最高准确率，则保存模型
    train_accuracy = eval(model, x_test, y_test)
    if train_accuracy > best_accuracy:
        best_accuracy = train_accuracy
        model.save_model(cnn, MODEL_PATH, overwrite=True)
        print("step %d, best accuracy %g" % (i, best_accuracy))

    print(str(i) + "/" + str(args.EPOCHS))
