# %%
from PIL import Image

# %%
Image.open('data/input/image/TCGA_CS_4941_19960909_11.tif')
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=256x256 at 0x7F60886BC1D0>

# %%
Image.open('data/input/label/TCGA_CS_4941_19960909_11_mask.tif')
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=256x256 at 0x7F60890ADC88>

# %%
[Image.open('data/input/label/TCGA_CS_4941_19960909_'+str(i)+'_mask.tif').show() for i in range(1,24)]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
Image.open('data/input/label/TCGA_CS_4941_19960909_11_mask.tif')
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=256x256 at 0x7F60890ADC88>

# %%
Image.open('data/input/label/TCGA_CS_4941_19960909_12_mask.tif')
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=256x256 at 0x7F60884DB470>

# %%
Image.open('data/input/label/TCGA_CS_4941_19960909_13_mask.tif')
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=256x256 at 0x7F60884DB0F0>

# %%
# each mask instance has a different color, from zero to N, where
# N is the number of instances. In order to make visualization easier,
# let's adda color palette to the mask.
mask.putpalette([
    0, 0, 0, # black background
    255, 0, 0, # index 1 is red
    255, 255, 0, # index 2 is yellow
    255, 153, 0, # index 3 is orange
])
mask
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-36bd39989539> in <module>
#       7     255, 0, 0, # index 1 is red
#       8     255, 255, 0, # index 2 is yellow
# ----> 9     255, 153, 0, # index 3 is orange
#      10 ])
#      11 mask
#
# ~/anaconda3/envs/fastv1/lib/python3.7/site-packages/PIL/Image.py in putpalette(self, data, rawmode)
#    1645
#    1646         if self.mode not in ("L", "LA", "P", "PA"):
# -> 1647             raise ValueError("illegal image mode")
#    1648         self.load()
#    1649         if isinstance(data, ImagePalette.ImagePalette):
#
# ValueError: illegal image mode

# %%
import pandas as pd

# %%
df=pd.read_csv('data/input/dev.csv')

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import pandas as pd

# %%
#from flyai.processor.download import check_download

from path import DATA_PATH

# %%
DATA_PATH
# Out:
# '/mnt/Hdd/Proj/github/flyai/vision/MRISegmentation_FlyAI/data/input'

# %%
class MRIDataset(Dataset):
    def __init__(self,root,df,transforms = None):
        self.root = root
        self.df = df
        self.transforms = transforms
        self.imgs = df.image_path
        self.masks = df.label_path
    
    def __getitem__(self,idx):
        # load images ad masks
        img_path = os.path.join(self.root, self.imgs[idx])
        mask_path = os.path.join(self.root, self.masks[idx])
        img = Image.open(img_path).convert("RGB")
        # note that we haven't converted the mask to RGB,
        # because each color corresponds to a different instance
        # with 0 being background
        mask = Image.open(mask_path)

        mask = np.array(mask)
        # instances are encoded as different colors
        obj_ids = np.unique(mask)
        # first id is the background, so remove it
        obj_ids = obj_ids[1:]

        # split the color-encoded mask into a set
        # of binary masks
        masks = mask == obj_ids[:, None, None]

        # get bounding box coordinates for each mask
        num_objs = len(obj_ids)
        boxes = []
        try:
            for i in range(num_objs):
                pos = np.where(masks[i])
                xmin = np.min(pos[1])
                xmax = np.max(pos[1])
                ymin = np.min(pos[0])
                ymax = np.max(pos[0])
                boxes.append([xmin, ymin, xmax, ymax])

            boxes = torch.as_tensor(boxes, dtype=torch.float32)
            area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        except:
            boxes = []
            area = 0
        # there is only one class
        labels = torch.ones((num_objs,), dtype=torch.int64)
        masks = torch.as_tensor(masks, dtype=torch.uint8)

        image_id = torch.tensor([idx])
        
        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["masks"] = masks
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.imgs)

# %%
ds = MRIDataset(DATA_PATH,df)

# %%
df
# Out:
#                             image_path  \
# 0    image/TCGA_CS_4941_19960909_1.tif
# 1    image/TCGA_CS_4941_19960909_2.tif
# 2    image/TCGA_CS_4941_19960909_3.tif
# 3    image/TCGA_CS_4941_19960909_4.tif
# 4    image/TCGA_CS_4941_19960909_5.tif
# 5    image/TCGA_CS_4941_19960909_6.tif
# 6    image/TCGA_CS_4941_19960909_7.tif
# 7    image/TCGA_CS_4941_19960909_8.tif
# 8    image/TCGA_CS_4941_19960909_9.tif
# 9   image/TCGA_CS_4941_19960909_10.tif
# 10  image/TCGA_CS_4941_19960909_11.tif
# 11  image/TCGA_CS_4941_19960909_12.tif
# 12  image/TCGA_CS_4941_19960909_13.tif
# 13  image/TCGA_CS_4941_19960909_14.tif
# 14  image/TCGA_CS_4941_19960909_15.tif
# 15  image/TCGA_CS_4941_19960909_16.tif
# 16  label/TCGA_CS_4941_19960909_17_mask.tif
# 17  label/TCGA_CS_4941_19960909_18_mask.tif
# 18  label/TCGA_CS_4941_19960909_19_mask.tif
# 19  label/TCGA_CS_4941_19960909_20_mask.tif
# 20  label/TCGA_CS_4941_19960909_21_mask.tif
# 21  label/TCGA_CS_4941_19960909_22_mask.tif
# 22  label/TCGA_CS_4941_19960909_23_mask.tif
# 23   label/TCGA_CS_4942_19970222_1_mask.tif
# 24   label/TCGA_CS_4942_19970222_2_mask.tif
# 25   label/TCGA_CS_4942_19970222_3_mask.tif
# 26   label/TCGA_CS_4942_19970222_4_mask.tif
# 27   label/TCGA_CS_4942_19970222_5_mask.tif
# 28   label/TCGA_CS_4942_19970222_6_mask.tif
# 29   label/TCGA_CS_4942_19970222_7_mask.tif
# ..                                      ...
# 70   label/TCGA_CS_4944_20010208_8_mask.tif
# 71   label/TCGA_CS_4944_20010208_9_mask.tif
# 72  label/TCGA_CS_4944_20010208_10_mask.tif
# 73  label/TCGA_CS_4944_20010208_11_mask.tif
# 74  label/TCGA_CS_4944_20010208_12_mask.tif
# 75  label/TCGA_CS_4944_20010208_13_mask.tif
# 76  label/TCGA_CS_4944_20010208_14_mask.tif
# 77  label/TCGA_CS_4944_20010208_15_mask.tif
# 78  label/TCGA_CS_4944_20010208_16_mask.tif
# 79  label/TCGA_CS_4944_20010208_17_mask.tif
# 80  label/TCGA_CS_4944_20010208_18_mask.tif
# 81  label/TCGA_CS_4944_20010208_19_mask.tif
# 82  label/TCGA_CS_4944_20010208_20_mask.tif
# 83   label/TCGA_CS_5393_19990606_1_mask.tif
# 84   label/TCGA_CS_5393_19990606_2_mask.tif
# 85   label/TCGA_CS_5393_19990606_3_mask.tif
# 86   label/TCGA_CS_5393_19990606_4_mask.tif
# 87   label/TCGA_CS_5393_19990606_5_mask.tif
# 88   label/TCGA_CS_5393_19990606_6_mask.tif
# 89   label/TCGA_CS_5393_19990606_7_mask.tif
# 90   label/TCGA_CS_5393_19990606_8_mask.tif
# 91   label/TCGA_CS_5393_19990606_9_mask.tif
# 92  label/TCGA_CS_5393_19990606_10_mask.tif
# 93  label/TCGA_CS_5393_19990606_11_mask.tif
# 94  label/TCGA_CS_5393_19990606_12_mask.tif
# 95  label/TCGA_CS_5393_19990606_13_mask.tif
# 96  label/TCGA_CS_5393_19990606_14_mask.tif
# 97  label/TCGA_CS_5393_19990606_15_mask.tif
# 98  label/TCGA_CS_5393_19990606_16_mask.tif
# 99  label/TCGA_CS_5393_19990606_17_mask.tif
#
# [100 rows x 2 columns]

# %%
df.iloc[10]
# Out:
# image_path         image/TCGA_CS_4941_19960909_11.tif
# label_path    label/TCGA_CS_4941_19960909_11_mask.tif
# Name: 10, dtype: object

# %%
ds[10]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-a25e3b14953c> in <module>
# ----> 1 ds[10]
#
# <ipython-input-21-2e6dfd5f82b8> in __getitem__(self, idx)
#      32         for i in range(num_objs):
#      33             pos = np.where(masks[i])
# ---> 34             xmin = np.min(pos[1])
#      35             xmax = np.max(pos[1])
#      36             ymin = np.min(pos[0])
#
# ~/anaconda3/envs/fastv1/lib/python3.7/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial)
#    2616     """
#    2617     return _wrapreduction(a, np.minimum, 'min', axis, None, out, keepdims=keepdims,
# -> 2618                           initial=initial)
#    2619
#    2620
#
# ~/anaconda3/envs/fastv1/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# ValueError: zero-size array to reduction operation minimum which has no identity
