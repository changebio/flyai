# %%
# -*- coding: utf-8 -*
import argparse
import codecs
import os.path
import tensorflow as tf
from flyai.dataset import Dataset

from model import Model

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
tf.logging.set_verbosity(tf.logging.ERROR)

FLAGS = None

from keras.backend.tensorflow_backend import set_session

feat_type = 'mfcc'  ##'dmfcc'#None  'normmfcc'
label_smooth = False

import sys

#sys.stdout = codecs.getwriter("utf-8")(sys.stdout.detach())

# 超参
parser = argparse.ArgumentParser()
# 111902 约等于512*200
parser.add_argument("-e", "--EPOCHS", default=100, type=int, help="train epochs")
parser.add_argument("-b", "--BATCH", default=4, type=int, help="batch size")
args = parser.parse_args([])

dataset = Dataset()
model_helper = Model(dataset, do_train=True)


def main():
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    config.gpu_options.per_process_gpu_memory_fraction = 0.5
    sess = tf.InteractiveSession(config=config)
    set_session(sess)
    cnn_model = model_helper.model
    cnn_model.train_model(sess, dataset, model_helper, args.BATCH, args.EPOCHS)


main()
# Out:
# Training from step: %d  0
# Step #0: accuracy 0.0%, cross entropy 2.428042
# Step #1: accuracy 0.0%, cross entropy 5.121532
# Step #2: accuracy 0.0%, cross entropy 3.812975
# Step #3: accuracy 0.0%, cross entropy 3.055591
# Step #4: accuracy 0.0%, cross entropy 2.481549
# Step #5: accuracy 0.0%, cross entropy 2.498734
# Step #6: accuracy 0.0%, cross entropy 2.572368
# Step #7: accuracy 0.0%, cross entropy 2.478633
# Step #8: accuracy 0.0%, cross entropy 2.482681
# Step #9: accuracy 0.0%, cross entropy 2.485181
# Step #10: accuracy 0.0%, cross entropy 2.486040
# Step #11: accuracy 25.0%, cross entropy 2.472271
# save model
# Step #12: accuracy 0.0%, cross entropy 2.490784
# Step #13: accuracy 0.0%, cross entropy 2.489871
# Step #14: accuracy 25.0%, cross entropy 2.512790
# Step #15: accuracy 0.0%, cross entropy 2.482457
# Step #16: accuracy 25.0%, cross entropy 2.518957
# Step #17: accuracy 0.0%, cross entropy 2.480301
# Step #18: accuracy 0.0%, cross entropy 2.482372
# Step #19: accuracy 25.0%, cross entropy 2.482635
# Step #20: accuracy 25.0%, cross entropy 2.495090
# Step #21: accuracy 25.0%, cross entropy 2.449828
# Step #22: accuracy 0.0%, cross entropy 2.468540
# Step #23: accuracy 25.0%, cross entropy 2.446522
# Step #24: accuracy 0.0%, cross entropy 2.562686
# Step #25: accuracy 25.0%, cross entropy 2.527638
# Step #26: accuracy 25.0%, cross entropy 2.372136
# Step #27: accuracy 0.0%, cross entropy 2.488382
# Step #28: accuracy 0.0%, cross entropy 2.541711
# Step #29: accuracy 25.0%, cross entropy 2.439182
# Step #30: accuracy 25.0%, cross entropy 2.706454
# Step #31: accuracy 0.0%, cross entropy 2.452762
# Step #32: accuracy 0.0%, cross entropy 2.521745
# Step #33: accuracy 0.0%, cross entropy 2.423318
# Step #34: accuracy 0.0%, cross entropy 2.601891
# Step #35: accuracy 25.0%, cross entropy 2.484469
# Step #36: accuracy 0.0%, cross entropy 2.511720
# Step #37: accuracy 25.0%, cross entropy 2.475042
# Step #38: accuracy 25.0%, cross entropy 2.430157
# Step #39: accuracy 0.0%, cross entropy 2.523090
# Step #40: accuracy 50.0%, cross entropy 2.140305
# save model
# Step #41: accuracy 0.0%, cross entropy 2.550176
# Step #42: accuracy 0.0%, cross entropy 2.668209
# Step #43: accuracy 0.0%, cross entropy 2.530305
# Step #44: accuracy 0.0%, cross entropy 2.476453
# Step #45: accuracy 25.0%, cross entropy 2.368097
# Step #46: accuracy 25.0%, cross entropy 2.525689
# Step #47: accuracy 0.0%, cross entropy 2.393454
# Step #48: accuracy 50.0%, cross entropy 1.899418
# Step #49: accuracy 50.0%, cross entropy 2.306376
# Step #50: accuracy 25.0%, cross entropy 2.267663
# Step #51: accuracy 0.0%, cross entropy 2.436739
# Step #52: accuracy 0.0%, cross entropy 2.399320
# Step #53: accuracy 0.0%, cross entropy 2.625019
# Step #54: accuracy 0.0%, cross entropy 2.459186
# Step #55: accuracy 0.0%, cross entropy 2.244348
# Step #56: accuracy 50.0%, cross entropy 2.447844
# Step #57: accuracy 25.0%, cross entropy 2.342659
# Step #58: accuracy 50.0%, cross entropy 1.980639
# Step #59: accuracy 50.0%, cross entropy 2.211721
# Step #60: accuracy 0.0%, cross entropy 2.429250
# Step #61: accuracy 0.0%, cross entropy 2.339964
# Step #62: accuracy 75.0%, cross entropy 1.985002
# save model
# Step #63: accuracy 25.0%, cross entropy 1.917659
# Step #64: accuracy 25.0%, cross entropy 2.342539
# Step #65: accuracy 0.0%, cross entropy 2.770824
# Step #66: accuracy 25.0%, cross entropy 1.509074
# Step #67: accuracy 25.0%, cross entropy 2.165491
# Step #68: accuracy 50.0%, cross entropy 1.774510
# Step #69: accuracy 25.0%, cross entropy 1.819130
# Step #70: accuracy 25.0%, cross entropy 2.177754
# Step #71: accuracy 0.0%, cross entropy 2.207885
# Step #72: accuracy 25.0%, cross entropy 2.196652
# Step #73: accuracy 25.0%, cross entropy 2.213341
# Step #74: accuracy 50.0%, cross entropy 1.971170
# Step #75: accuracy 50.0%, cross entropy 2.183721
# Step #76: accuracy 50.0%, cross entropy 2.147332
# Step #77: accuracy 50.0%, cross entropy 1.833915
# Step #78: accuracy 50.0%, cross entropy 1.736166
# Step #79: accuracy 25.0%, cross entropy 2.055134
# Step #80: accuracy 50.0%, cross entropy 2.092742
# Step #81: accuracy 75.0%, cross entropy 1.862003
# Step #82: accuracy 50.0%, cross entropy 1.982359
# Step #83: accuracy 25.0%, cross entropy 1.967412
# Step #84: accuracy 50.0%, cross entropy 1.799811
# Step #85: accuracy 25.0%, cross entropy 2.142568
# Step #86: accuracy 50.0%, cross entropy 2.038758
# Step #87: accuracy 25.0%, cross entropy 2.002537
# Step #88: accuracy 50.0%, cross entropy 1.639198
# Step #89: accuracy 75.0%, cross entropy 1.605834
# Step #90: accuracy 50.0%, cross entropy 1.721637
# Step #91: accuracy 25.0%, cross entropy 1.771556
# Step #92: accuracy 75.0%, cross entropy 0.787733
# Step #93: accuracy 25.0%, cross entropy 1.752870
# Step #94: accuracy 75.0%, cross entropy 0.916578
# Step #95: accuracy 50.0%, cross entropy 0.929725
# Step #96: accuracy 75.0%, cross entropy 0.994478
# Step #97: accuracy 100.0%, cross entropy 0.751627
# save model
# Step #98: accuracy 50.0%, cross entropy 1.415443
# Step #99: accuracy 50.0%, cross entropy 1.572589

# %%
[i.shape for i in dataset.get_all_processor_data()]
# Out:
# [(100, 3920), (100, 12), (100, 3920), (100, 12)]
